# %% [markdown]
# <a href="https://colab.research.google.com/github/safry4/data_analysis/blob/main/Vytas_foncomap_plots_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from google.colab import drive
from google.colab import files
drive.mount("/content/drive", force_remount=True)
from matplotlib.colors import to_rgba
import seaborn as sns
from scipy.stats import mannwhitneyu

import scipy.stats as stats
import math
# Out:
# Mounted at /content/drive

# %%
#knockouts_serine 473

# %%
# data_path = '/content/drive/MyDrive/24-01-30 Results/Slide 3 (1)/Results/well 5/'
# os.chdir(data_path)
# files = os.listdir(data_path)
# files

# %%
#Slide 3
data_path = '/content/drive/MyDrive/24-01-30 Results/Slide 3 (1)/Results/well 5/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
serine_nucleai_scv_w5 = [f for f in files if 'nucleai' in f]
serine_df_nucleai_w5 = pd.DataFrame()
for f in serine_nucleai_scv_w5:
    data = pd.read_csv(f)
    serine_df_nucleai_w5 = serine_df_nucleai_w5._append(data)

#cytoplasm
serine_cytoplasm_scv_w5 = [f for f in files if 'cytoplasm' in f]
serine_df_cytoplasm_w5 = pd.DataFrame()
for f in serine_cytoplasm_scv_w5:
    data = pd.read_csv(f)
    serine_df_cytoplasm_w5 = serine_df_cytoplasm_w5._append(data)

#mixed
serine_mixed_scv_w5 = [f for f in files if 'mixed' in f]
serine_df_mixed_w5 = pd.DataFrame()
for f in serine_mixed_scv_w5:
    data = pd.read_csv(f)
    serine_df_mixed_w5 = serine_df_mixed_w5._append(data)


#Slide 3
data_path = '/content/drive/MyDrive/24-01-30 Results/Slide 3 (1)/Results/well 6/Results/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
serine_nucleai_scv_w6 = [f for f in files if 'nucleai' in f]
serine_df_nucleai_w6 = pd.DataFrame()
for f in serine_nucleai_scv_w6:
    data = pd.read_csv(f)
    serine_df_nucleai_w6 = serine_df_nucleai_w6._append(data)

#cytoplasm
serine_cytoplasm_scv_w6 = [f for f in files if 'cytoplasm' in f]
serine_df_cytoplasm_w6 = pd.DataFrame()
for f in serine_cytoplasm_scv_w6:
    data = pd.read_csv(f)
    serine_df_cytoplasm_w6 = serine_df_cytoplasm_w6._append(data)

#mixed
serine_mixed_scv_w6 = [f for f in files if 'mixed' in f]
serine_df_mixed_w6 = pd.DataFrame()
for f in serine_mixed_scv_w6:
    data = pd.read_csv(f)
    serine_df_mixed_w6 = serine_df_mixed_w6._append(data)

# %%
#Slide 4
#a == well 5
data_path = '/content/drive/MyDrive/24-01-30 Results/Slide 4 (1)/a/Results/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
serine_nucleai_s4_w5 = [f for f in files if 'nucleai' in f]
serine_df_nucleai_s4_w5 = pd.DataFrame()
for f in serine_nucleai_s4_w5:
    data = pd.read_csv(f)
    serine_df_nucleai_s4_w5 = serine_df_nucleai_s4_w5._append(data)

#cytoplasm
serine_cytoplasm_s4_w5 = [f for f in files if 'cytoplasm' in f]
serine_df_cytoplasm_s4_w5 = pd.DataFrame()
for f in serine_cytoplasm_s4_w5:
    data = pd.read_csv(f)
    serine_df_cytoplasm_s4_w5 = serine_df_cytoplasm_s4_w5._append(data)

#mixed
serine_mixed_s4_w5 = [f for f in files if 'mixed' in f]
serine_df_mixed_s4_w5 = pd.DataFrame()
for f in serine_mixed_s4_w5:
    data = pd.read_csv(f)
    serine_df_mixed_s4_w5 = serine_df_mixed_s4_w5._append(data)

#Slide 4
#b == well 6
data_path = data_path = '/content/drive/MyDrive/24-01-30 Results/Slide 4 (1)/b/Results/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
serine_nucleai_s4_w6 = [f for f in files if 'nucleai' in f]
serine_df_nucleai_s4_w6 = pd.DataFrame()
for f in serine_nucleai_s4_w6:
    data = pd.read_csv(f)
    serine_df_nucleai_s4_w6 = serine_df_nucleai_s4_w6._append(data)

#cytoplasm
serine_cytoplasm_s4_w6 = [f for f in files if 'cytoplasm' in f]
serine_df_cytoplasm_s4_w6 = pd.DataFrame()
for f in serine_cytoplasm_s4_w6:
    data = pd.read_csv(f)
    serine_df_cytoplasm_s4_w6 = serine_df_cytoplasm_s4_w6._append(data)

#mixed
serine_mixed_s4_w6 = [f for f in files if 'mixed' in f]
serine_df_mixed_s4_w6 = pd.DataFrame()
for f in serine_mixed_s4_w6:
    data = pd.read_csv(f)
    serine_df_mixed_s4_w6 = serine_df_mixed_s4_w6._append(data)

# %%
#well5
serine_nucleai_w5 = pd.DataFrame()
serine_nucleai_w5 = serine_nucleai_w5._append(serine_df_nucleai_w5)
serine_nucleai_w5 = serine_nucleai_w5._append(serine_df_nucleai_s4_w5)

serine_cytoplasm_w5 = pd.DataFrame()
serine_cytoplasm_w5 = serine_cytoplasm_w5._append(serine_df_cytoplasm_w5)
serine_cytoplasm_w5 = serine_cytoplasm_w5._append(serine_df_cytoplasm_s4_w5)

serine_mixed_w5 = pd.DataFrame()
serine_mixed_w5 = serine_mixed_w5._append(serine_df_mixed_w5)
serine_mixed_w5 = serine_mixed_w5._append(serine_df_mixed_s4_w5)

#well 6
serine_nucleai_w6 = pd.DataFrame()
serine_nucleai_w6 = serine_nucleai_w6._append(serine_df_nucleai_w6)
serine_nucleai_w6 = serine_nucleai_w6._append(serine_df_nucleai_s4_w6)

serine_cytoplasm_w6 = pd.DataFrame()
serine_cytoplasm_w6 = serine_cytoplasm_w6._append(serine_df_cytoplasm_w6)
serine_cytoplasm_w6 = serine_cytoplasm_w6._append(serine_df_cytoplasm_s4_w6)

serine_mixed_w6 = pd.DataFrame()
serine_mixed_w6 = serine_mixed_w6._append(serine_df_mixed_w6)
serine_mixed_w6 = serine_mixed_w6._append(serine_df_mixed_s4_w6)

# %%
#F10_vs_K/O
#cyto
serine_cyto_WT = serine_cytoplasm_w5['mean_intensity']
serine_cyto_WT = serine_cyto_WT.reset_index()
serine_cyto_WT = serine_cyto_WT['mean_intensity']

serine_cyto_KO = serine_cytoplasm_w6['mean_intensity']
serine_cyto_KO = serine_cyto_KO.reset_index()
serine_cyto_KO = serine_cyto_KO['mean_intensity']

data = [serine_cyto_WT, serine_cyto_KO]
dat = pd.DataFrame({'WTB16F10': pd.Series(serine_cyto_WT), 'K/O PITPNC1': pd.Series(serine_cyto_KO)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_cyto_F10= np.median(serine_cyto_WT)
medians_cyto_Knockout = np.median(serine_cyto_KO)

# medians_S8b_nucleai= np.median(S8b_nucleai)
# medians_S8b_cytoplasm = np.median(S8b_cytoplasm)


plt.annotate(round(medians_cyto_F10,2), xy=(0.1, 1.66),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_cyto_Knockout,2), xy=(1.1, 1.72),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_nucleai,2), xy=(2.1, 0.12),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_cytoplasm,2), xy=(3.1, 0.59),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Cytoplasm', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-8-db68d7c33390>:21: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#F10_vs_K/O
serine_nucleai_WT = serine_nucleai_w5['mean_intensity']
serine_nucleai_WT = serine_nucleai_WT.reset_index()
serine_nucleai_WT = serine_nucleai_WT['mean_intensity']

serine_nucleai_KO = serine_nucleai_w6['mean_intensity']
serine_nucleai_KO = serine_nucleai_KO.reset_index()
serine_nucleai_KO = serine_nucleai_KO['mean_intensity']

data = [serine_nucleai_WT, serine_nucleai_KO]
dat = pd.DataFrame({'WTB16F10': pd.Series(serine_nucleai_WT), 'K/O PITPNC1': pd.Series(serine_nucleai_KO)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_Nuclei_F10= np.median(serine_nucleai_WT)
medians_Nuclei_Knockout = np.median(serine_nucleai_KO)

# medians_S8b_nucleai= np.median(S8b_nucleai)
# medians_S8b_cytoplasm = np.median(S8b_cytoplasm)


plt.annotate(round(medians_Nuclei_F10,2), xy=(0.1, 1.72),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_Nuclei_Knockout,2), xy=(1.1, 1.4),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_nucleai,2), xy=(2.1, 0.12),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_cytoplasm,2), xy=(3.1, 0.59),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Nuclei', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-9-6d9f4237c287>:20: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#no average nuclei

#F10_vs_K/O
serine_nucleai_WT_a = serine_df_nucleai_w5['mean_intensity']
serine_nucleai_WT_a = serine_nucleai_WT_a.reset_index()
serine_nucleai_WT_a = serine_nucleai_WT_a['mean_intensity']

serine_nucleai_WT_a2 = serine_df_nucleai_s4_w5['mean_intensity']
serine_nucleai_WT_a2 = serine_nucleai_WT_a2.reset_index()
serine_nucleai_WT_a2 = serine_nucleai_WT_a2['mean_intensity']

serine_nucleai_KO_b = serine_df_nucleai_w6['mean_intensity']
serine_nucleai_KO_b = serine_nucleai_KO_b.reset_index()
serine_nucleai_KO_b = serine_nucleai_KO_b['mean_intensity']

serine_nucleai_KO_b2 = serine_df_nucleai_s4_w6['mean_intensity']
serine_nucleai_KO_b2 = serine_nucleai_KO_b2.reset_index()
serine_nucleai_KO_b2 = serine_nucleai_KO_b2['mean_intensity']

data = [serine_nucleai_WT_a, serine_nucleai_WT_a2, serine_nucleai_KO_b, serine_nucleai_KO_b2]
dat = pd.DataFrame({'WTB16F10 \nSlide 3': pd.Series(serine_nucleai_WT_a), 'WTB16F10 \nSlide4': pd.Series(serine_nucleai_WT_a2),'K/O PITPNC1 \nSlide 3': pd.Series(serine_nucleai_KO_b),'K/O PITPNC1 \nSlide4': pd.Series(serine_nucleai_KO_b2)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_serine_nucleai_WT_a= np.median(serine_nucleai_WT_a)
medians_serine_nucleai_WT_a2 = np.median(serine_nucleai_WT_a2)

medians_serine_nucleai_KO_b= np.median(serine_nucleai_KO_b)
medians_serine_nucleai_KO_b2 = np.median(serine_nucleai_KO_b2)


plt.annotate(round(medians_serine_nucleai_WT_a,2), xy=(0.1, 3.82),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_nucleai_WT_a2,2), xy=(1.1, 0.01),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_nucleai_KO_b,2), xy=(2.1, 4.05),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_nucleai_KO_b2,2), xy=(3.1, 0.03),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Nuclei no average', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-10-5deb6ca6b0c1>:30: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#no average nuclei rearranged

#F10_vs_K/O
serine_nucleai_WT_a = serine_df_nucleai_w5['mean_intensity']
serine_nucleai_WT_a = serine_nucleai_WT_a.reset_index()
serine_nucleai_WT_a = serine_nucleai_WT_a['mean_intensity']

serine_nucleai_WT_a2 = serine_df_nucleai_s4_w5['mean_intensity']
serine_nucleai_WT_a2 = serine_nucleai_WT_a2.reset_index()
serine_nucleai_WT_a2 = serine_nucleai_WT_a2['mean_intensity']

serine_nucleai_KO_b = serine_df_nucleai_w6['mean_intensity']
serine_nucleai_KO_b = serine_nucleai_KO_b.reset_index()
serine_nucleai_KO_b = serine_nucleai_KO_b['mean_intensity']

serine_nucleai_KO_b2 = serine_df_nucleai_s4_w6['mean_intensity']
serine_nucleai_KO_b2 = serine_nucleai_KO_b2.reset_index()
serine_nucleai_KO_b2 = serine_nucleai_KO_b2['mean_intensity']

data = [serine_nucleai_WT_a, serine_nucleai_WT_a2, serine_nucleai_KO_b, serine_nucleai_KO_b2]
dat = pd.DataFrame({'WTB16F10 \nExperiment 1': pd.Series(serine_nucleai_WT_a),'K/O PITPNC1 \nExperiment 1': pd.Series(serine_nucleai_KO_b), 'WTB16F10 \nExperiment 2': pd.Series(serine_nucleai_WT_a2),'K/O PITPNC1 \nExperiment 2': pd.Series(serine_nucleai_KO_b2)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=4, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

#sns.violinplot(data=dat,  scale='count', palette='flare')
ax = sns.violinplot(data=dat, palette="flare", linewidth = 2)

serine_nucleai_WT_a_pvalue = serine_nucleai_WT_a[(serine_nucleai_WT_a > 4) & (serine_nucleai_WT_a <= serine_nucleai_WT_a.quantile(0.75))]
serine_nucleai_KO_b_pvalue = serine_nucleai_KO_b[(serine_nucleai_KO_b > 4) & (serine_nucleai_KO_b <= serine_nucleai_KO_b.quantile(0.75))]

serine_nucleai_WT_a2_pvalue = serine_nucleai_WT_a2[(serine_nucleai_WT_a2 > 4) & (serine_nucleai_WT_a2 <= serine_nucleai_WT_a2.quantile(0.75))]
serine_nucleai_KO_b2_pvalue = serine_nucleai_KO_b2[(serine_nucleai_KO_b2 > 4) & (serine_nucleai_KO_b2 <= serine_nucleai_KO_b2.quantile(0.75))]


#short range
U1, p1 = mannwhitneyu(serine_nucleai_WT_a_pvalue, serine_nucleai_KO_b_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = ns" , xy=(0.7, 33),weight='bold')
#p2 = 0.6905114448525407

# #whole range
U1, p2 = mannwhitneyu(serine_nucleai_WT_a, serine_nucleai_KO_b, method="exact")
ax.annotate("p = ns", xy=(0.7, 31),weight='bold')
#p2 = 0.397408977607659

#short range
#U1, p1 = mannwhitneyu(serine_nucleai_WT_a2_pvalue, serine_nucleai_KO_b2_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = None" , xy=(2.4, 33),weight='bold')
#p2 = 0.6905114448525407

# #whole range
U1, p2 = mannwhitneyu(serine_nucleai_WT_a2, serine_nucleai_KO_b2, method="exact")
ax.annotate("p = ns", xy=(2.4, 31),weight='bold')
#p2 = 0.1836062868277721

for violin in ax.collections:
    violin.set_alpha(0.85)

sns.stripplot(data=dat,   size =1, color="black").set( ylabel='% FRET Efficiency (Ef)')



q75, q50, q25 = np.percentile(serine_nucleai_WT_a, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(0.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(0.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(0.1, round(q25,2)-0.2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_nucleai_KO_b, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(1.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(1.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(1.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_nucleai_WT_a2, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(2.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(2.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(2.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_nucleai_KO_b2, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(3.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(3.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(3.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
# medians_serine_nucleai_WT_a= np.median(serine_nucleai_WT_a)
# medians_serine_nucleai_WT_a2 = np.median(serine_nucleai_WT_a2)

# medians_serine_nucleai_KO_b= np.median(serine_nucleai_KO_b)
# medians_serine_nucleai_KO_b2 = np.median(serine_nucleai_KO_b2)


# plt.annotate(round(medians_serine_nucleai_WT_a,2), xy=(0.1, 3.82),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_nucleai_WT_a2,2), xy=(1.1, 0.01),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_nucleai_KO_b,2), xy=(2.1, 4.05),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_nucleai_KO_b2,2), xy=(3.1, 0.03),fontsize = 16, weight='bold', color='darkblue')

#sns.stripplot(data=dat,   size=1, color="black")
#plt.xlabel('Nuclei no average', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');

# %%
p2
# Out:
# 0.1836062868277721

# %%
#no average cyto

#F10_vs_K/O
serine_cyto_WT_a = serine_df_cytoplasm_w5['mean_intensity']
serine_cyto_WT_a = serine_cyto_WT_a.reset_index()
serine_cyto_WT_a = serine_cyto_WT_a['mean_intensity']

serine_cyto_WT_a2 = serine_df_cytoplasm_s4_w5['mean_intensity']
serine_cyto_WT_a2 = serine_cyto_WT_a2.reset_index()
serine_cyto_WT_a2 = serine_cyto_WT_a2['mean_intensity']

serine_cyto_KO_b = serine_df_cytoplasm_w6['mean_intensity']
serine_cyto_KO_b = serine_cyto_KO_b.reset_index()
serine_cyto_KO_b = serine_cyto_KO_b['mean_intensity']

serine_cyto_KO_b2 = serine_df_cytoplasm_s4_w6['mean_intensity']
serine_cyto_KO_b2 = serine_cyto_KO_b2.reset_index()
serine_cyto_KO_b2 = serine_cyto_KO_b2['mean_intensity']

data = [serine_cyto_WT_a, serine_cyto_WT_a2, serine_cyto_KO_b, serine_cyto_KO_b2]
dat = pd.DataFrame({'WTB16F10 \nSlide 3': pd.Series(serine_cyto_WT_a), 'WTB16F10 \nSlide4': pd.Series(serine_cyto_WT_a2),'K/O PITPNC1 \nSlide 3': pd.Series(serine_cyto_KO_b),'K/O PITPNC1 \nSlide4': pd.Series(serine_cyto_KO_b2)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_serine_cyto_WT_a= np.median(serine_cyto_WT_a)
medians_serine_cyto_WT_a2 = np.median(serine_cyto_WT_a2)

medians_serine_cyto_KO_b= np.median(serine_cyto_KO_b)
medians_serine_cyto_KO_b2 = np.median(serine_cyto_KO_b2)


plt.annotate(round(medians_serine_cyto_WT_a,2), xy=(0.1, 3.3),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_cyto_WT_a2,2), xy=(1.1, 0.03),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_cyto_KO_b,2), xy=(2.1, 4.03),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_serine_cyto_KO_b2,2), xy=(3.1, 0.12),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Cytoplasm no average', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-13-956f7c77f86a>:30: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#no average cyto rearrange

#F10_vs_K/O
serine_cyto_WT_a = serine_df_cytoplasm_w5['mean_intensity']
serine_cyto_WT_a = serine_cyto_WT_a.reset_index()
serine_cyto_WT_a = serine_cyto_WT_a['mean_intensity']

serine_cyto_WT_a2 = serine_df_cytoplasm_s4_w5['mean_intensity']
serine_cyto_WT_a2 = serine_cyto_WT_a2.reset_index()
serine_cyto_WT_a2 = serine_cyto_WT_a2['mean_intensity']

serine_cyto_KO_b = serine_df_cytoplasm_w6['mean_intensity']
serine_cyto_KO_b = serine_cyto_KO_b.reset_index()
serine_cyto_KO_b = serine_cyto_KO_b['mean_intensity']

serine_cyto_KO_b2 = serine_df_cytoplasm_s4_w6['mean_intensity']
serine_cyto_KO_b2 = serine_cyto_KO_b2.reset_index()
serine_cyto_KO_b2 = serine_cyto_KO_b2['mean_intensity']

data = [serine_cyto_WT_a, serine_cyto_WT_a2, serine_cyto_KO_b, serine_cyto_KO_b2]
dat = pd.DataFrame({'WTB16F10 \nExperiment 1': pd.Series(serine_cyto_WT_a), 'K/O PITPNC1 \nExperiment 1': pd.Series(serine_cyto_KO_b),'WTB16F10 \nExperiment 2': pd.Series(serine_cyto_WT_a2),'K/O PITPNC1 \nExperiment 2': pd.Series(serine_cyto_KO_b2)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=4, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

#sns.violinplot(data=dat,  scale='count', palette='flare')
ax = sns.violinplot(data=dat, palette="flare", linewidth = 2)

serine_cyto_WT_a_pvalue = serine_cyto_WT_a[(serine_cyto_WT_a > 4) & (serine_cyto_WT_a <= serine_cyto_WT_a.quantile(0.75))]
serine_cyto_KO_b_pvalue = serine_cyto_KO_b[(serine_cyto_KO_b > 4) & (serine_cyto_KO_b <= serine_cyto_KO_b.quantile(0.75))]

serine_cyto_WT_a2_pvalue = serine_cyto_WT_a2[(serine_cyto_WT_a2 > 4) & (serine_cyto_WT_a2 <= serine_cyto_WT_a2.quantile(0.75))]
serine_cyto_KO_b2_pvalue = serine_cyto_KO_b2[(serine_cyto_KO_b2 > 4) & (serine_cyto_KO_b2 <= serine_cyto_KO_b2.quantile(0.75))]


#short range
U1, p1 = mannwhitneyu(serine_cyto_WT_a_pvalue, serine_cyto_KO_b_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = ns" , xy=(0.7, 33),weight='bold')
#p1 = 0.12960568842921785

# # #whole range
U1, p2 = mannwhitneyu(serine_cyto_WT_a, serine_cyto_KO_b, method="exact")
ax.annotate("p = ns", xy=(0.7, 31),weight='bold')
#p2 = 0.7633658976022405

# #short range
#U1, p1 = mannwhitneyu(serine_cyto_WT_a2_pvalue, serine_cyto_KO_b2_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = None" , xy=(2.4, 33),weight='bold')
#p2 = 0.6905114448525407

# # #whole range
U1, p2 = mannwhitneyu(serine_cyto_WT_a2, serine_cyto_KO_b2, method="exact")
ax.annotate("p = *", xy=(2.4, 31),weight='bold')
#p2 = 0.016893654302876107

for violin in ax.collections:
    violin.set_alpha(0.85)

sns.stripplot(data=dat,   size =1, color="black").set( ylabel='% FRET Efficiency (Ef)')



q75, q50, q25 = np.percentile(serine_cyto_WT_a, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(0.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(0.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(0.1, round(q25,2)-0.7),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_cyto_KO_b, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(1.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(1.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(1.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_cyto_WT_a2, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(2.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(2.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(2.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(serine_cyto_KO_b2, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(3.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(3.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(3.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# # #medians
# medians_serine_cyto_WT_a= np.median(serine_cyto_WT_a)
# medians_serine_cyto_WT_a2 = np.median(serine_cyto_WT_a2)

# medians_serine_cyto_KO_b= np.median(serine_cyto_KO_b)
# medians_serine_cyto_KO_b2 = np.median(serine_cyto_KO_b2)


# plt.annotate(round(medians_serine_cyto_WT_a,2), xy=(0.1, 3.3),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_cyto_WT_a2,2), xy=(1.1, 0.03),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_cyto_KO_b,2), xy=(2.1, 4.03),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_serine_cyto_KO_b2,2), xy=(3.1, 0.12),fontsize = 16, weight='bold', color='darkblue')

#sns.stripplot(data=dat,   size=1, color="black")
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');

# %%
p2
# Out:
# 0.016893654302876107

# %%
#####

# %%
#S3
data_path = '/content/drive/MyDrive/14_10/S3'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S3 = [f for f in files if 'nucleai' in f]
df_nucleai_S3 = pd.DataFrame()
for f in nucleai_scv_S3:
    data = pd.read_csv(f)
    df_nucleai_S3 = df_nucleai_S3._append(data)

#cytoplasm
cytoplasm_scv_S3 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S3 = pd.DataFrame()
for f in cytoplasm_scv_S3:
    data = pd.read_csv(f)
    df_cytoplasm_S3 = df_cytoplasm_S3._append(data)

#mixed
mixed_scv_S3 = [f for f in files if 'mixed' in f]
df_mixed_S3 = pd.DataFrame()
for f in mixed_scv_S3:
    data = pd.read_csv(f)
    df_mixed_S3 = df_mixed_S3._append(data)


#S6
data_path = '/content/drive/MyDrive/14_10/S6'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S6 = [f for f in files if 'nucleai' in f]
df_nucleai_S6 = pd.DataFrame()
for f in nucleai_scv_S6:
    data = pd.read_csv(f)
    df_nucleai_S6 = df_nucleai_S6._append(data)

#cytoplasm
cytoplasm_scv_S6 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S6 = pd.DataFrame()
for f in cytoplasm_scv_S6:
    data = pd.read_csv(f)
    df_cytoplasm_S6 = df_cytoplasm_S6._append(data)

#mixed
mixed_scv_S6 = [f for f in files if 'mixed' in f]
df_mixed_S6 = pd.DataFrame()
for f in mixed_scv_S6:
    data = pd.read_csv(f)
    df_mixed_S6 = df_mixed_S6._append(data)

# %%
# #Thresholds
# t_break = 3.5
# t_1 = 10.0
# t_2 = 20.0
# t_3 = 30.0

# df_nucleai_S3_list = []

# less_t_break = round((df_nucleai_S3[df_nucleai_S3["mean_intensity"] < t_break].shape[0]/df_nucleai_S3.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_nucleai_S3[(df_nucleai_S3["mean_intensity"] >= t_break) & (df_nucleai_S3["mean_intensity"] < t_1)].shape[0])/df_nucleai_S3.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_nucleai_S3[(df_nucleai_S3["mean_intensity"] >= t_1) & (df_nucleai_S3["mean_intensity"] < t_2)].shape[0])/df_nucleai_S3.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_nucleai_S3[(df_nucleai_S3["mean_intensity"] >= t_2) & (df_nucleai_S3["mean_intensity"] < t_3)].shape[0])/df_nucleai_S3.shape[0])*100,2)
# more_30_0 =  round(((df_nucleai_S3[(df_nucleai_S3["mean_intensity"] >= t_3)].shape[0])/df_nucleai_S3.shape[0])*100,2)

# df_nucleai_S3_list.append(less_t_break)
# df_nucleai_S3_list.append(more_t_break_less_t_1)
# df_nucleai_S3_list.append(more_t_1_less_20_0)
# df_nucleai_S3_list.append(more_20_0_less_30_0)
# df_nucleai_S3_list.append(more_30_0)

# print('df_nucleai_S3_list', df_nucleai_S3_list)

# df_cytoplasm_S3_list = []

# less_t_break = round((df_cytoplasm_S3[df_cytoplasm_S3["mean_intensity"] < t_break].shape[0]/df_cytoplasm_S3.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_cytoplasm_S3[(df_cytoplasm_S3["mean_intensity"] >= t_break) & (df_cytoplasm_S3["mean_intensity"] < t_1)].shape[0])/df_cytoplasm_S3.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_cytoplasm_S3[(df_cytoplasm_S3["mean_intensity"] >= t_1) & (df_cytoplasm_S3["mean_intensity"] < t_2)].shape[0])/df_cytoplasm_S3.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_cytoplasm_S3[(df_cytoplasm_S3["mean_intensity"] >= t_2) & (df_cytoplasm_S3["mean_intensity"] < t_3)].shape[0])/df_cytoplasm_S3.shape[0])*100,2)
# more_30_0 =  round(((df_cytoplasm_S3[(df_cytoplasm_S3["mean_intensity"] >= t_3)].shape[0])/df_cytoplasm_S3.shape[0])*100,2)

# df_cytoplasm_S3_list.append(less_t_break)
# df_cytoplasm_S3_list.append(more_t_break_less_t_1)
# df_cytoplasm_S3_list.append(more_t_1_less_20_0)
# df_cytoplasm_S3_list.append(more_20_0_less_30_0)
# df_cytoplasm_S3_list.append(more_30_0)

# print('df_cytoplasm_S3_list', df_cytoplasm_S3_list)

# df_mixed_S3_list = []

# less_t_break = round((df_mixed_S3[df_mixed_S3["mean_intensity"] < t_break].shape[0]/df_mixed_S3.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_mixed_S3[(df_mixed_S3["mean_intensity"] >= t_break) & (df_mixed_S3["mean_intensity"] < t_1)].shape[0])/df_mixed_S3.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_mixed_S3[(df_mixed_S3["mean_intensity"] >= t_1) & (df_mixed_S3["mean_intensity"] < t_2)].shape[0])/df_mixed_S3.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_mixed_S3[(df_mixed_S3["mean_intensity"] >= t_2) & (df_mixed_S3["mean_intensity"] < t_3)].shape[0])/df_mixed_S3.shape[0])*100,2)
# more_30_0 =  round(((df_mixed_S3[(df_mixed_S3["mean_intensity"] >= t_3)].shape[0])/df_mixed_S3.shape[0])*100,2)

# df_mixed_S3_list.append(less_t_break)
# df_mixed_S3_list.append(more_t_break_less_t_1)
# df_mixed_S3_list.append(more_t_1_less_20_0)
# df_mixed_S3_list.append(more_20_0_less_30_0)
# df_mixed_S3_list.append(more_30_0)

# print('df_mixed_S3_list', df_mixed_S3_list)

# ###
# df_nucleai_S6_list = []

# less_t_break = round((df_nucleai_S6[df_nucleai_S6["mean_intensity"] < t_break].shape[0]/df_nucleai_S6.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_nucleai_S6[(df_nucleai_S6["mean_intensity"] >= t_break) & (df_nucleai_S6["mean_intensity"] < t_1)].shape[0])/df_nucleai_S6.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_nucleai_S6[(df_nucleai_S6["mean_intensity"] >= t_1) & (df_nucleai_S6["mean_intensity"] < t_2)].shape[0])/df_nucleai_S6.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_nucleai_S6[(df_nucleai_S6["mean_intensity"] >= t_2) & (df_nucleai_S6["mean_intensity"] < t_3)].shape[0])/df_nucleai_S6.shape[0])*100,2)
# more_30_0 =  round(((df_nucleai_S6[(df_nucleai_S6["mean_intensity"] >= t_3)].shape[0])/df_nucleai_S6.shape[0])*100,2)

# df_nucleai_S6_list.append(less_t_break)
# df_nucleai_S6_list.append(more_t_break_less_t_1)
# df_nucleai_S6_list.append(more_t_1_less_20_0)
# df_nucleai_S6_list.append(more_20_0_less_30_0)
# df_nucleai_S6_list.append(more_30_0)

# print('df_nucleai_S6_list', df_nucleai_S6_list)

# df_cytoplasm_S6_list = []

# less_t_break = round((df_cytoplasm_S6[df_cytoplasm_S6["mean_intensity"] < t_break].shape[0]/df_cytoplasm_S6.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_cytoplasm_S6[(df_cytoplasm_S6["mean_intensity"] >= t_break) & (df_cytoplasm_S6["mean_intensity"] < t_1)].shape[0])/df_cytoplasm_S6.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_cytoplasm_S6[(df_cytoplasm_S6["mean_intensity"] >= t_1) & (df_cytoplasm_S6["mean_intensity"] < t_2)].shape[0])/df_cytoplasm_S6.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_cytoplasm_S6[(df_cytoplasm_S6["mean_intensity"] >= t_2) & (df_cytoplasm_S6["mean_intensity"] < t_3)].shape[0])/df_cytoplasm_S6.shape[0])*100,2)
# more_30_0 =  round(((df_cytoplasm_S6[(df_cytoplasm_S6["mean_intensity"] >= t_3)].shape[0])/df_cytoplasm_S6.shape[0])*100,2)

# df_cytoplasm_S6_list.append(less_t_break)
# df_cytoplasm_S6_list.append(more_t_break_less_t_1)
# df_cytoplasm_S6_list.append(more_t_1_less_20_0)
# df_cytoplasm_S6_list.append(more_20_0_less_30_0)
# df_cytoplasm_S6_list.append(more_30_0)

# print('df_cytoplasm_S6_list', df_cytoplasm_S6_list)

# df_mixed_S6_list = []

# less_t_break = round((df_mixed_S6[df_mixed_S6["mean_intensity"] < t_break].shape[0]/df_mixed_S6.shape[0])*100,2)
# more_t_break_less_t_1 =  round(((df_mixed_S6[(df_mixed_S6["mean_intensity"] >= t_break) & (df_mixed_S6["mean_intensity"] < t_1)].shape[0])/df_mixed_S6.shape[0])*100,2)
# more_t_1_less_20_0 =  round(((df_mixed_S6[(df_mixed_S6["mean_intensity"] >= t_1) & (df_mixed_S6["mean_intensity"] < t_2)].shape[0])/df_mixed_S6.shape[0])*100,2)
# more_20_0_less_30_0 =  round(((df_mixed_S6[(df_mixed_S6["mean_intensity"] >= t_2) & (df_mixed_S6["mean_intensity"] < t_3)].shape[0])/df_mixed_S6.shape[0])*100,2)
# more_30_0 =  round(((df_mixed_S6[(df_mixed_S6["mean_intensity"] >= t_3)].shape[0])/df_mixed_S6.shape[0])*100,2)

# df_mixed_S6_list.append(less_t_break)
# df_mixed_S6_list.append(more_t_break_less_t_1)
# df_mixed_S6_list.append(more_t_1_less_20_0)
# df_mixed_S6_list.append(more_20_0_less_30_0)
# df_mixed_S6_list.append(more_30_0)

# print('df_mixed_S6_list', df_mixed_S6_list)

# %%
# #Mixed
# x = np.arange(0,51,1)
# plt.figure(figsize=(15, 5))
# plt.xticks(range(len(x)), x)
# plt.ylim([0, 100])

# ax = plt.gca()

# #S3
# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_mixed_S3_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_mixed_S3_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_mixed_S3_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_mixed_S3_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_mixed_S3_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# #S6
# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_mixed_S6_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_mixed_S6_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_mixed_S6_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_mixed_S6_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_mixed_S6_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# # x_start, x_end = 30.00, 50.0
# # y_start, y_end = 0, 0
# # ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('black', 0.5), lw=2))

# ax.vlines(x=3.5, ymin=0, ymax=100, colors='red', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=10.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=20.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')



# ax.set(xlabel = 'FRET-efficiency (%)' ,ylabel='% of Samples within the range')
# #ax.margins(0.05)
# # ax.set_ylim(bottom=0)
# #plt.legend(loc='upper right')

# ax.set_title('Difference in mixed cells',  fontsize = 14)

# plt.show()

# %%
# #Cytoplasm
# x = np.arange(0,51,1)
# plt.figure(figsize=(15, 5))
# plt.xticks(range(len(x)), x)
# plt.ylim([0, 100])

# ax = plt.gca()

# #S3
# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_cytoplasm_S3_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_cytoplasm_S3_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_cytoplasm_S3_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_cytoplasm_S3_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_cytoplasm_S3_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# #S6
# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_cytoplasm_S6_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_cytoplasm_S6_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_cytoplasm_S6_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_cytoplasm_S6_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_cytoplasm_S6_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# # x_start, x_end = 30.00, 50.0
# # y_start, y_end = 0, 0
# # ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('black', 0.5), lw=2))

# ax.vlines(x=3.5, ymin=0, ymax=100, colors='red', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=10.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=20.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')



# ax.set(xlabel = 'FRET-efficiency (%)' ,ylabel='% of Samples within the range')
# #ax.margins(0.05)
# # ax.set_ylim(bottom=0)
# #plt.legend(loc='upper right')

# ax.set_title('Difference in cytoplasm',  fontsize = 14)
# ax.legend(['First line', 'Second line'])

# plt.show()

# %%
# #add vertical line at 3.5 dashed red
# #add statistic p value
# #rearrange thresholds
# #add new colum to a table to set
# #x = df_nucleai_S3_list
# x = df_nucleai_S3["mean_intensity"].to_list()
# y = df_cytoplasm_S3_list
# z = df_mixed_S3_list

# xweights = 100 * np.ones_like(x) / len(x)
# yweights = 100 * np.ones_like(y) / len(y)
# zweights = 100 * np.ones_like(z) / len(z)

# #fig, ax = plt.subplots()

# # ax = plt.gca()
# # ax.add_patch(plt.Rectangle((0.0, 0), 3.5 - 0.0, 38.3 - 0,  lw=2))
# # plt.show()

# import matplotlib.pyplot as plt
# from matplotlib.colors import to_rgba

# #x = ['1', '2', '3', '4', '21', '28']
# x = np.arange(0,51,1)
# plt.figure(figsize=(15, 5))
# plt.xticks(range(len(x)), x)
# plt.ylim([0, 100])

# ax = plt.gca()

# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_nucleai_S3_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_nucleai_S3_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_nucleai_S3_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_nucleai_S3_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_nucleai_S3_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('crimson', 0.2), lw=2))

# #S6
# x_start, x_end = 0, 3.5
# y_start, y_end = 0, df_nucleai_S6_list[0]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 3.5, 10.0
# y_start, y_end = 0, df_nucleai_S6_list[1]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 10.00, 20.0
# y_start, y_end = 0, df_nucleai_S6_list[2]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 20.00, 30.0
# y_start, y_end = 0, df_nucleai_S6_list[3]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# x_start, x_end = 30.00, 50.0
# y_start, y_end = 0, df_nucleai_S6_list[4]
# ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('blue', 0.2), lw=2))

# # x_start, x_end = 30.00, 50.0
# # y_start, y_end = 0, 0
# # ax.add_patch(plt.Rectangle((x_start, y_start), x_end - x_start, y_end - y_start, facecolor=to_rgba('black', 0.5), lw=2))

# ax.vlines(x=3.5, ymin=0, ymax=100, colors='red', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=10.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')
# ax.vlines(x=20.0, ymin=0, ymax=100, colors='blue', ls=':', lw=2, label='vline_single - full height')



# ax.set(xlabel = 'FRET-efficiency (%)' ,ylabel='% of Samples within the range')
# #ax.margins(0.05)
# # ax.set_ylim(bottom=0)
# #plt.legend(loc='upper right')

# ax.set_title('Difference in nuclei',  fontsize = 14)

# plt.show()

# #ax.hist(x, [0, 3.5, 10, 20, 30], orientation="vertical", color='lightblue', alpha=0.5, label="nucleai_S3")
# # ax.hist(post['Acceptor Intensity'], 15,  orientation="horizontal", color='salmon', alpha=0.5, label="post-treatment")
# # ax.hist(post['Acceptor Intensity'], 15,  orientation="horizontal", color='salmon', alpha=0.5, label="post-treatment")

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy import stats

# N = 100000
# # x = np.random.randn(N)
# x = stats.norm.rvs(size=N)
# num_bins = 20
# plt.hist(x, bins=num_bins, facecolor='blue', alpha=0.5)

# y = np.linspace(-4, 4, 1000)
# bin_width = (x.max() - x.min()) / num_bins
# plt.plot(y, stats.norm.pdf(y) * N * bin_width)

# plt.show()

# %%
# #10_20
# hist_S3 = df_nucleai_S3[(df_nucleai_S3['mean_intensity'] > 10)&(df_nucleai_S3['mean_intensity'] < 20)]['mean_intensity']
# hist_S6 = df_nucleai_S6[(df_nucleai_S6['mean_intensity'] > 10)&(df_nucleai_S6['mean_intensity'] < 20)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import scipy.stats as stats
# import math

# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.120, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.165, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(14.51,0.125))
# plt.annotate(str(round(mu,2)),xy=(12.71,0.155))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S3 = df_nucleai_S3[(df_nucleai_S3['mean_intensity'] > 3.5)&(df_nucleai_S3['mean_intensity'] < 10)]['mean_intensity']
# hist_S6 = df_nucleai_S6[(df_nucleai_S6['mean_intensity'] > 3.5)&(df_nucleai_S6['mean_intensity'] < 10)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.245, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.23, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(5.75,0.235))
# plt.annotate(str(round(mu,2)),xy=(7.15,0.23))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #0_3.5
# hist_S3 = df_nucleai_S3[(df_nucleai_S3['mean_intensity'] > 0)&(df_nucleai_S3['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S6 = df_nucleai_S6[(df_nucleai_S6['mean_intensity'] > 0)&(df_nucleai_S6['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.46, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.32, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(1.1,0.45))
# plt.annotate(str(round(mu,2)),xy=(1.9,0.33))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S3 = df_nucleai_S3[(df_nucleai_S3['mean_intensity'] > 3.5)&(df_nucleai_S3['mean_intensity'] < 20)]['mean_intensity']
# hist_S6 = df_nucleai_S6[(df_nucleai_S6['mean_intensity'] > 3.5)&(df_nucleai_S6['mean_intensity'] < 20)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.07, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.11, colors='crimson' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(1.1,0.45))
# plt.annotate(str(round(mu,1)),xy=(9.4,0.03))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#cyto

# %%
# #10_20
# hist_S3 = df_cytoplasm_S3[(df_cytoplasm_S3['mean_intensity'] > 10)&(df_cytoplasm_S3['mean_intensity'] < 20)]['mean_intensity']
# hist_S6 = df_cytoplasm_S6[(df_cytoplasm_S6['mean_intensity'] > 10)&(df_cytoplasm_S6['mean_intensity'] < 20)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.145, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.225, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(14.51,0.155))
# plt.annotate(str(round(mu,2)),xy=(13.71,0.225))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S3 = df_cytoplasm_S3[(df_cytoplasm_S3['mean_intensity'] > 3.5)&(df_cytoplasm_S3['mean_intensity'] < 10)]['mean_intensity']
# hist_S6 = df_cytoplasm_S6[(df_cytoplasm_S6['mean_intensity'] > 3.5)&(df_cytoplasm_S6['mean_intensity'] < 10)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.18, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.3, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(5.6,0.155))
# plt.annotate(str(round(mu,2)),xy=(5.3,0.3))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #0_3.5

# hist_S3 = df_cytoplasm_S3[(df_cytoplasm_S3['mean_intensity'] > 0)&(df_cytoplasm_S3['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S6 = df_cytoplasm_S6[(df_cytoplasm_S6['mean_intensity'] > 0)&(df_cytoplasm_S6['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.415, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.43, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(0.9,0.43))
# plt.annotate(str(round(mu,2)),xy=(2.2,0.425))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20

# hist_S3 = df_cytoplasm_S3[(df_cytoplasm_S3['mean_intensity'] > 3.5)&(df_cytoplasm_S3['mean_intensity'] < 20)]['mean_intensity']
# hist_S6 = df_cytoplasm_S6[(df_cytoplasm_S6['mean_intensity'] > 3.5)&(df_cytoplasm_S6['mean_intensity'] < 20)]['mean_intensity']

# hist_S3 = hist_S3.sort_values()
# hist_S6 = hist_S6.sort_values()

# %%
# mu = np.mean(hist_S3)
# variance = np.var(hist_S3)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6)
# variance = np.var(hist_S6)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.082, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.109, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(9.3,0.085))
# plt.annotate(str(round(mu,2)),xy=(7.13,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# count, bins, ignored = plt.hist(x1, 20, density=True)
# plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
#                np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
#          linewidth=2, color='r')
# plt.show()

# %%
# fit_alpha, fit_loc, fit_beta=stats.gamma.fit(hist_S3)

# %%
# import numpy as np
# from scipy.stats import gamma
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(1, 1)

# %%
# a = 1.99
# mean, var, skew, kurt = gamma.stats(a, moments='mvsk')

# %%
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt

# #define x-axis values
# #x = np.linspace (0, 40, 100)
# x1 = hist_S3.copy()
# x2 = hist_S6.copy()

# #calculate pdf of Gamma distribution for each x-value
# y1 = stats.gamma.pdf(x1, a=2, scale=2)
# y2 = stats.gamma.pdf(x2, a=2, scale=2)

# #create plot of Gamma distribution
# plt.plot(x1, y1, color = 'red')
# plt.plot(x2, y2, color = 'green')

# #display plot
# plt.show()

# %%
# N = 100000
# # x = np.random.randn(N)
# x = hist_S6
# num_bins = 20
# plt.hist(x, bins=num_bins, facecolor='pink', alpha=0.5)

# y = np.linspace(10, 20, 10)
# bin_width = (x.max() - x.min()) / num_bins
# plt.plot(y, stats.norm.pdf(y) * N * bin_width)

# plt.show()

# %%
#S4a
data_path = '/content/drive/MyDrive/Vytas_analysis/S4a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S4a = [f for f in files if 'nucleai' in f]
df_nucleai_S4a = pd.DataFrame()
for f in nucleai_scv_S4a:
    data = pd.read_csv(f)
    df_nucleai_S4a = df_nucleai_S4a._append(data)

#cytoplasm
cytoplasm_scv_S4a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S4a = pd.DataFrame()
for f in cytoplasm_scv_S4a:
    data = pd.read_csv(f)
    df_cytoplasm_S4a = df_cytoplasm_S4a._append(data)

#mixed
mixed_scv_S4a = [f for f in files if 'mixed' in f]
df_mixed_S4a = pd.DataFrame()
for f in mixed_scv_S4a:
    data = pd.read_csv(f)
    df_mixed_S4a = df_mixed_S4a._append(data)


#S7a
data_path = '/content/drive/MyDrive/Vytas_analysis/S7a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S7a = [f for f in files if 'nucleai' in f]
df_nucleai_S7a = pd.DataFrame()
for f in nucleai_scv_S7a:
    data = pd.read_csv(f)
    df_nucleai_S7a = df_nucleai_S7a._append(data)

#cytoplasm
cytoplasm_scv_S7a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S7a = pd.DataFrame()
for f in cytoplasm_scv_S7a:
    data = pd.read_csv(f)
    df_cytoplasm_S7a = df_cytoplasm_S7a._append(data)

#mixed
mixed_scv_S7a = [f for f in files if 'mixed' in f]
df_mixed_S7a = pd.DataFrame()
for f in mixed_scv_S7a:
    data = pd.read_csv(f)
    df_mixed_S7a = df_mixed_S7a._append(data)

# %%
# #0_3.5
# hist_S4a = df_nucleai_S4a[(df_nucleai_S4a['mean_intensity'] > 0)&(df_nucleai_S4a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 0)&(df_nucleai_S7a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.51, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.37, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.45))
# plt.annotate(str(round(mu,2)),xy=(mu,0.39))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S4a = df_nucleai_S4a[(df_nucleai_S4a['mean_intensity'] > 3.5)&(df_nucleai_S4a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 3.5)&(df_nucleai_S7a['mean_intensity'] < 10)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #one value
# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.245, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.185, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.235))
# plt.annotate(str(round(mu,2)),xy=(mu,0.16))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S4a = df_nucleai_S4a[(df_nucleai_S4a['mean_intensity'] > 10)&(df_nucleai_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 10)&(df_nucleai_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# #no blue values
# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #no blue values
# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.120, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.142, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(14.51,0.125))
# plt.annotate(str(round(mu,2)),xy=(mu,0.125))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20

# hist_S4a = df_nucleai_S4a[(df_nucleai_S4a['mean_intensity'] > 3.5)&(df_nucleai_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 3.5)&(df_nucleai_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #no blue
# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.07, colors='blue' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.094, colors='crimson' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(1.1,0.45))
# plt.annotate(str(round(mu,1)),xy=(mu,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#cytoplasm

# %%
# #0_3.5
# hist_S4a = df_cytoplasm_S4a[(df_cytoplasm_S4a['mean_intensity'] > 0)&(df_cytoplasm_S4a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 0)&(df_cytoplasm_S7a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=1.9, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.42, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,1.75))
# plt.annotate(str(round(mu,2)),xy=(mu,0.50))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S4a = df_cytoplasm_S4a[(df_cytoplasm_S4a['mean_intensity'] > 3.5)&(df_cytoplasm_S4a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 3.5)&(df_cytoplasm_S7a['mean_intensity'] < 10)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=1.9, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.2, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,1.75))
# plt.annotate(str(round(mu,2)),xy=(mu,0.18))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S4a = df_cytoplasm_S4a[(df_cytoplasm_S4a['mean_intensity'] > 10)&(df_cytoplasm_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 10)&(df_cytoplasm_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=1.9, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=3.0, colors='crimson' , alpha = 0.3, ls=':')
# #plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,1.75))
# plt.annotate(str(round(mu,2)),xy=(mu,3.0))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S4a = df_cytoplasm_S4a[(df_cytoplasm_S4a['mean_intensity'] > 3.5)&(df_cytoplasm_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 3.5)&(df_cytoplasm_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=1.9, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.175, colors='crimson' , alpha = 0.3, ls=':')
# #plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,1.75))
# plt.annotate(str(round(mu,2)),xy=(mu,0.175))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#mixed

# %%
# #0_3.5
# hist_S4a = df_mixed_S4a[(df_mixed_S4a['mean_intensity'] > 0)&(df_mixed_S4a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 0)&(df_mixed_S7a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=2.35, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.36, colors='crimson' , alpha = 0.3, ls=':')
# #plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,2.05))
# plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10.0
# hist_S4a = df_mixed_S4a[(df_mixed_S4a['mean_intensity'] > 3.5)&(df_mixed_S4a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 3.5)&(df_mixed_S7a['mean_intensity'] < 10)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=2.35, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.245, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,2.05))
# plt.annotate(str(round(mu,2)),xy=(mu,0.25))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S4a = df_mixed_S4a[(df_mixed_S4a['mean_intensity'] > 10)&(df_mixed_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 10)&(df_mixed_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=2.35, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.5, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,2.05))
# plt.annotate(str(round(mu,2)),xy=(mu,0.45))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S4a = df_mixed_S4a[(df_mixed_S4a['mean_intensity'] > 3.5)&(df_mixed_S4a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 3.5)&(df_mixed_S7a['mean_intensity'] < 20)]['mean_intensity']

# hist_S4a = hist_S4a.sort_values()
# hist_S7a = hist_S7a.sort_values()

# %%
# mu = np.mean(hist_S4a)
# variance = np.var(hist_S4a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=2.35, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.133, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,2.05))
# plt.annotate(str(round(mu,2)),xy=(mu,0.11))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#S5a
data_path = '/content/drive/MyDrive/Vytas_analysis/S5a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S5a = [f for f in files if 'nucleai' in f]
df_nucleai_S5a = pd.DataFrame()
for f in nucleai_scv_S5a:
    data = pd.read_csv(f)
    df_nucleai_S5a = df_nucleai_S5a._append(data)

#cytoplasm
cytoplasm_scv_S5a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S5a = pd.DataFrame()
for f in cytoplasm_scv_S5a:
    data = pd.read_csv(f)
    df_cytoplasm_S5a = df_cytoplasm_S5a._append(data)

#mixed
mixed_scv_S5a = [f for f in files if 'mixed' in f]
df_mixed_S5a = pd.DataFrame()
for f in mixed_scv_S5a:
    data = pd.read_csv(f)
    df_mixed_S5a = df_mixed_S5a._append(data)


#S8a
data_path = '/content/drive/MyDrive/Vytas_analysis/S8a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S8a = [f for f in files if 'nucleai' in f]
df_nucleai_S8a = pd.DataFrame()
for f in nucleai_scv_S8a:
    data = pd.read_csv(f)
    df_nucleai_S8a = df_nucleai_S8a._append(data)

#cytoplasm
cytoplasm_scv_S8a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S8a = pd.DataFrame()
for f in cytoplasm_scv_S8a:
    data = pd.read_csv(f)
    df_cytoplasm_S8a = df_cytoplasm_S8a._append(data)

#mixed
mixed_scv_S8a = [f for f in files if 'mixed' in f]
df_mixed_S8a = pd.DataFrame()
for f in mixed_scv_S8a:
    data = pd.read_csv(f)
    df_mixed_S8a = df_mixed_S8a._append(data)

# %%
# #0_3.5
# hist_S5a = df_nucleai_S5a[(df_nucleai_S5a['mean_intensity'] > 0)&(df_nucleai_S5a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 0)&(df_nucleai_S8a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S5a = df_nucleai_S5a[(df_nucleai_S5a['mean_intensity'] > 3.5)&(df_nucleai_S5a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 3.5)&(df_nucleai_S8a['mean_intensity'] < 10)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #one value
# plt.vlines(x=mu2, ymin=-0.00, ymax=0.165, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.215, colors='crimson' , alpha = 0.3, ls=':')
# #plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.17))
# plt.annotate(str(round(mu,2)),xy=(mu,0.2))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S5a = df_nucleai_S5a[(df_nucleai_S5a['mean_intensity'] > 10)&(df_nucleai_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 10)&(df_nucleai_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# #no blue values
# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #one blue value
# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.120, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.175, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(14.51,0.125))
# plt.annotate(str(round(mu,2)),xy=(mu,0.165))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20

# hist_S5a = df_nucleai_S5a[(df_nucleai_S5a['mean_intensity'] > 3.5)&(df_nucleai_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 3.5)&(df_nucleai_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #no blue
# plt.vlines(x=mu2, ymin=-0.00, ymax=0.098, colors='blue' , alpha = 0.3, ls=':')
# #plt.hlines(y=0, xmin=3.5, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.12, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.09))
# plt.annotate(str(round(mu,1)),xy=(mu,0.12))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #cyto

# #0_3.5
# hist_S5a = df_cytoplasm_S5a[(df_cytoplasm_S5a['mean_intensity'] > 0)&(df_cytoplasm_S5a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 0)&(df_cytoplasm_S8a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.33, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.51, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.3))
# plt.annotate(str(round(mu,2)),xy=(mu,0.45))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S5a = df_cytoplasm_S5a[(df_cytoplasm_S5a['mean_intensity'] > 3.5)&(df_cytoplasm_S5a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 3.5)&(df_cytoplasm_S8a['mean_intensity'] < 10)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.47, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.23, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.42))
# plt.annotate(str(round(mu,2)),xy=(mu,0.25))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S5a = df_cytoplasm_S5a[(df_cytoplasm_S5a['mean_intensity'] > 10)&(df_cytoplasm_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 10)&(df_cytoplasm_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# # plt.vlines(x=mu2, ymin=-0.00, ymax=0.47, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.23, colors='crimson' , alpha = 0.3, ls=':')

# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(mu2,0.42))
# # plt.annotate(str(round(mu,2)),xy=(mu,0.25))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S5a = df_cytoplasm_S5a[(df_cytoplasm_S5a['mean_intensity'] > 3.5)&(df_cytoplasm_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 3.5)&(df_cytoplasm_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.09, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.16, colors='crimson' , alpha = 0.3, ls=':')

# # plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# # plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.10))
# plt.annotate(str(round(mu,2)),xy=(mu,0.15))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#mixed

# %%
# #0_3.5
# hist_S5a = df_mixed_S5a[(df_mixed_S5a['mean_intensity'] > 0)&(df_mixed_S5a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 0)&(df_mixed_S8a['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.41, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.45, colors='crimson' , alpha = 0.3, ls=':')

# # plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# # plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.40))
# plt.annotate(str(round(mu,2)),xy=(mu,0.42))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S5a = df_mixed_S5a[(df_mixed_S5a['mean_intensity'] > 3.5)&(df_mixed_S5a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 3.5)&(df_mixed_S8a['mean_intensity'] < 10)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.255, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.215, colors='crimson' , alpha = 0.3, ls=':')

# # plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# # plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.25))
# plt.annotate(str(round(mu,2)),xy=(mu,0.2))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S5a = df_mixed_S5a[(df_mixed_S5a['mean_intensity'] > 10)&(df_mixed_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 10)&(df_mixed_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.105, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.34, colors='crimson' , alpha = 0.3, ls=':')

# # plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# # plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.12))
# plt.annotate(str(round(mu,2)),xy=(mu,0.3))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S5a = df_mixed_S5a[(df_mixed_S5a['mean_intensity'] > 3.5)&(df_mixed_S5a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 3.5)&(df_mixed_S8a['mean_intensity'] < 20)]['mean_intensity']

# hist_S5a = hist_S5a.sort_values()
# hist_S8a = hist_S8a.sort_values()

# %%
# mu = np.mean(hist_S5a)
# variance = np.var(hist_S5a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.088, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.097, colors='crimson' , alpha = 0.3, ls=':')

# # plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')
# # plt.hlines(y=0.0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.09))
# plt.annotate(str(round(mu,2)),xy=(mu,0.085))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#knock-outs

# %%
#S6a_vs_S6b

# %%
#S6a
data_path = '/content/drive/MyDrive/14_10/S6'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S6a = [f for f in files if 'nucleai' in f]
df_nucleai_S6a = pd.DataFrame()
for f in nucleai_scv_S6a:
    data = pd.read_csv(f)
    df_nucleai_S6a = df_nucleai_S6a._append(data)

#cytoplasm
cytoplasm_scv_S6a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S6a = pd.DataFrame()
for f in cytoplasm_scv_S6a:
    data = pd.read_csv(f)
    df_cytoplasm_S6a = df_cytoplasm_S6a._append(data)

#mixed
mixed_scv_S6a = [f for f in files if 'mixed' in f]
df_mixed_S6a = pd.DataFrame()
for f in mixed_scv_S6a:
    data = pd.read_csv(f)
    df_mixed_S6a = df_mixed_S6a._append(data)

#S6b
data_path = '/content/drive/MyDrive/11_12/Analysis/S6/Tables'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S6b = [f for f in files if 'nucleai' in f]
df_nucleai_S6b = pd.DataFrame()
for f in nucleai_scv_S6b:
    data = pd.read_csv(f)
    df_nucleai_S6b = df_nucleai_S6b._append(data)

#cytoplasm
cytoplasm_scv_S6b = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S6b = pd.DataFrame()
for f in cytoplasm_scv_S6b:
    data = pd.read_csv(f)
    df_cytoplasm_S6b = df_cytoplasm_S6b._append(data)

#mixed
mixed_scv_S6b = [f for f in files if 'mixed' in f]
df_mixed_S6b = pd.DataFrame()
for f in mixed_scv_S6b:
    data = pd.read_csv(f)
    df_mixed_S6b = df_mixed_S6b._append(data)

# %%
#nucleai

# %%
# #0_3.5
# hist_S6a = df_nucleai_S6a[(df_nucleai_S6a['mean_intensity'] > 0)&(df_nucleai_S6a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S6b = df_nucleai_S6b[(df_nucleai_S6b['mean_intensity'] > 0)&(df_nucleai_S6b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.48, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.46, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.45))
# plt.annotate(str(round(mu,2)),xy=(mu,0.4))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S6a = df_nucleai_S6a[(df_nucleai_S6a['mean_intensity'] > 3.5)&(df_nucleai_S6a['mean_intensity'] < 10)]['mean_intensity']
# hist_S6b = df_nucleai_S6b[(df_nucleai_S6b['mean_intensity'] > 3.5)&(df_nucleai_S6b['mean_intensity'] < 10)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.205, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.245, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.2))
# plt.annotate(str(round(mu,2)),xy=(mu,0.22))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S6a = df_nucleai_S6a[(df_nucleai_S6a['mean_intensity'] > 10)&(df_nucleai_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_nucleai_S6b[(df_nucleai_S6b['mean_intensity'] > 10)&(df_nucleai_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.3, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.12, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.3))
# plt.annotate(str(round(mu,2)),xy=(mu,0.10))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S6a = df_nucleai_S6a[(df_nucleai_S6a['mean_intensity'] > 3.5)&(df_nucleai_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_nucleai_S6b[(df_nucleai_S6b['mean_intensity'] > 3.5)&(df_nucleai_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.105, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.078, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.1))
# plt.annotate(str(round(mu,2)),xy=(mu,0.08))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#cyto

# %%
# #0_3.5
# hist_S6a = df_cytoplasm_S6a[(df_cytoplasm_S6a['mean_intensity'] > 0)&(df_cytoplasm_S6a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S6b = df_cytoplasm_S6b[(df_cytoplasm_S6b['mean_intensity'] > 0)&(df_cytoplasm_S6b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.38, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.42, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.38))
# plt.annotate(str(round(mu,2)),xy=(mu,0.4))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S6a = df_cytoplasm_S6a[(df_cytoplasm_S6a['mean_intensity'] > 3.5)&(df_cytoplasm_S6a['mean_intensity'] < 10)]['mean_intensity']
# hist_S6b = df_cytoplasm_S6b[(df_cytoplasm_S6b['mean_intensity'] > 3.5)&(df_cytoplasm_S6b['mean_intensity'] < 10)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.195, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.18, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.18))
# plt.annotate(str(round(mu,2)),xy=(mu,0.16))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S6a = df_cytoplasm_S6a[(df_cytoplasm_S6a['mean_intensity'] > 10)&(df_cytoplasm_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_cytoplasm_S6b[(df_cytoplasm_S6b['mean_intensity'] > 10)&(df_cytoplasm_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.13, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.15, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.13))
# plt.annotate(str(round(mu,2)),xy=(mu,0.15))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S6a = df_cytoplasm_S6a[(df_cytoplasm_S6a['mean_intensity'] > 3.5)&(df_cytoplasm_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_cytoplasm_S6b[(df_cytoplasm_S6b['mean_intensity'] > 3.5)&(df_cytoplasm_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.074, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.082, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.08))
# plt.annotate(str(round(mu,2)),xy=(mu,0.05))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#mixed

# %%
# #0_3.5
# hist_S6a = df_mixed_S6a[(df_mixed_S6a['mean_intensity'] > 0)&(df_mixed_S6a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S6b = df_mixed_S6b[(df_mixed_S6b['mean_intensity'] > 0)&(df_mixed_S6b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.7, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.41, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.68))
# plt.annotate(str(round(mu,2)),xy=(mu,0.4))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S6a = df_mixed_S6a[(df_mixed_S6a['mean_intensity'] > 3.5)&(df_mixed_S6a['mean_intensity'] < 10)]['mean_intensity']
# hist_S6b = df_mixed_S6b[(df_mixed_S6b['mean_intensity'] > 3.5)&(df_mixed_S6b['mean_intensity'] < 10)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.255, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.21, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.25))
# plt.annotate(str(round(mu,2)),xy=(mu,0.2))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S6a = df_mixed_S6a[(df_mixed_S6a['mean_intensity'] > 10)&(df_mixed_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_mixed_S6b[(df_mixed_S6b['mean_intensity'] > 10)&(df_mixed_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.27, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.25))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S6a = df_mixed_S6a[(df_mixed_S6a['mean_intensity'] > 3.5)&(df_mixed_S6a['mean_intensity'] < 20)]['mean_intensity']
# hist_S6b = df_mixed_S6b[(df_mixed_S6b['mean_intensity'] > 3.5)&(df_mixed_S6b['mean_intensity'] < 20)]['mean_intensity']

# hist_S6a = hist_S6a.sort_values()
# hist_S6b = hist_S6b.sort_values()

# %%
# mu = np.mean(hist_S6a)
# variance = np.var(hist_S6a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S6b)
# variance = np.var(hist_S6b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.1, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.115, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.1))
# plt.annotate(str(round(mu,2)),xy=(mu,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#S7a_vs_S7b

# %%
#S7a
data_path = '/content/drive/MyDrive/Vytas_analysis/S7a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S7a = [f for f in files if 'nucleai' in f]
df_nucleai_S7a = pd.DataFrame()
for f in nucleai_scv_S7a:
    data = pd.read_csv(f)
    df_nucleai_S7a = df_nucleai_S7a._append(data)

#cytoplasm
cytoplasm_scv_S7a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S7a = pd.DataFrame()
for f in cytoplasm_scv_S7a:
    data = pd.read_csv(f)
    df_cytoplasm_S7a = df_cytoplasm_S7a._append(data)

#mixed
mixed_scv_S7a = [f for f in files if 'mixed' in f]
df_mixed_S7a = pd.DataFrame()
for f in mixed_scv_S7a:
    data = pd.read_csv(f)
    df_mixed_S7a = df_mixed_S7a._append(data)

#S7b
data_path = '/content/drive/MyDrive/11_12/Analysis/S7/Tables'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S7b = [f for f in files if 'nucleai' in f]
df_nucleai_S7b = pd.DataFrame()
for f in nucleai_scv_S7b:
    data = pd.read_csv(f)
    df_nucleai_S7b = df_nucleai_S7b._append(data)

#cytoplasm
cytoplasm_scv_S7b = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S7b = pd.DataFrame()
for f in cytoplasm_scv_S7b:
    data = pd.read_csv(f)
    df_cytoplasm_S7b = df_cytoplasm_S7b._append(data)

#mixed
mixed_scv_S7b = [f for f in files if 'mixed' in f]
df_mixed_S7b = pd.DataFrame()
for f in mixed_scv_S7b:
    data = pd.read_csv(f)
    df_mixed_S7b = df_mixed_S7b._append(data)

# %%
#ncleai

# %%
#0...3.5

# %%
# #0_3.5
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 0)&(df_nucleai_S7a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7b = df_nucleai_S7b[(df_nucleai_S7b['mean_intensity'] > 0)&(df_nucleai_S7b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.4, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.5, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.4))
# plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 3.5)&(df_nucleai_S7a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7b = df_nucleai_S7b[(df_nucleai_S7b['mean_intensity'] > 3.5)&(df_nucleai_S7b['mean_intensity'] < 10)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.31, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.3))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 10)&(df_nucleai_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_nucleai_S7b[(df_nucleai_S7b['mean_intensity'] > 10)&(df_nucleai_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.185, colors='blue' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.18))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S7a = df_nucleai_S7a[(df_nucleai_S7a['mean_intensity'] > 3.5)&(df_nucleai_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_nucleai_S7b[(df_nucleai_S7b['mean_intensity'] > 3.5)&(df_nucleai_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.098, colors='blue' , alpha = 0.3, ls=':')
# #plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.09))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#cytoplasm

# %%
# #0_3.5
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 0)&(df_cytoplasm_S7a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7b = df_cytoplasm_S7b[(df_cytoplasm_S7b['mean_intensity'] > 0)&(df_cytoplasm_S7b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=1.9, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,1.8))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 3.5)&(df_cytoplasm_S7a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7b = df_cytoplasm_S7b[(df_cytoplasm_S7b['mean_intensity'] > 3.5)&(df_cytoplasm_S7b['mean_intensity'] < 10)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.2, colors='blue' , alpha = 0.3, ls=':')
# #plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.2))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 10)&(df_cytoplasm_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_cytoplasm_S7b[(df_cytoplasm_S7b['mean_intensity'] > 10)&(df_cytoplasm_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# # plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# # plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S7a = df_cytoplasm_S7a[(df_cytoplasm_S7a['mean_intensity'] > 3.5)&(df_cytoplasm_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_cytoplasm_S7b[(df_cytoplasm_S7b['mean_intensity'] > 3.5)&(df_cytoplasm_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.195, colors='blue' , alpha = 0.3, ls=':')
# #plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.18))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#mixed

# %%
# #0_3.5
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 0)&(df_mixed_S7a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S7b = df_mixed_S7b[(df_mixed_S7b['mean_intensity'] > 0)&(df_mixed_S7b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.42, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=2.4, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,2.35))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 3.5)&(df_mixed_S7a['mean_intensity'] < 10)]['mean_intensity']
# hist_S7b = df_mixed_S7b[(df_mixed_S7b['mean_intensity'] > 3.5)&(df_mixed_S7b['mean_intensity'] < 10)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.205, colors='blue' , alpha = 0.3, ls=':')
# #plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.2))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 10)&(df_mixed_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_mixed_S7b[(df_mixed_S7b['mean_intensity'] > 10)&(df_mixed_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# # plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# # plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S7a = df_mixed_S7a[(df_mixed_S7a['mean_intensity'] > 3.5)&(df_mixed_S7a['mean_intensity'] < 20)]['mean_intensity']
# hist_S7b = df_mixed_S7b[(df_mixed_S7b['mean_intensity'] > 3.5)&(df_mixed_S7b['mean_intensity'] < 20)]['mean_intensity']

# hist_S7a = hist_S7a.sort_values()
# hist_S7b = hist_S7b.sort_values()

# %%
# mu = np.mean(hist_S7a)
# variance = np.var(hist_S7a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S7b)
# variance = np.var(hist_S7b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.205, colors='blue' , alpha = 0.3, ls=':')
# #plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.2))
# #plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#make from it!
#S8a_vs_S8b

# %%
#S8a
data_path = '/content/drive/MyDrive/Vytas_analysis/S8a/Analysis/'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S8a = [f for f in files if 'nucleai' in f]
df_nucleai_S8a = pd.DataFrame()
for f in nucleai_scv_S8a:
    data = pd.read_csv(f)
    df_nucleai_S8a = df_nucleai_S8a._append(data)

#cytoplasm
cytoplasm_scv_S8a = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S8a = pd.DataFrame()
for f in cytoplasm_scv_S8a:
    data = pd.read_csv(f)
    df_cytoplasm_S8a = df_cytoplasm_S8a._append(data)

#mixed
mixed_scv_S8a = [f for f in files if 'mixed' in f]
df_mixed_S8a = pd.DataFrame()
for f in mixed_scv_S8a:
    data = pd.read_csv(f)
    df_mixed_S8a = df_mixed_S8a._append(data)

#S8b
data_path = '/content/drive/MyDrive/11_12/Analysis/S8/Tables'
os.chdir(data_path)
files = os.listdir(data_path)
#files

#nucleai
nucleai_scv_S8b = [f for f in files if 'nucleai' in f]
df_nucleai_S8b = pd.DataFrame()
for f in nucleai_scv_S8b:
    data = pd.read_csv(f)
    df_nucleai_S8b = df_nucleai_S8b._append(data)

#cytoplasm
cytoplasm_scv_S8b = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_S8b = pd.DataFrame()
for f in cytoplasm_scv_S8b:
    data = pd.read_csv(f)
    df_cytoplasm_S8b = df_cytoplasm_S8b._append(data)

#mixed
mixed_scv_S8b = [f for f in files if 'mixed' in f]
df_mixed_S8b = pd.DataFrame()
for f in mixed_scv_S8b:
    data = pd.read_csv(f)
    df_mixed_S8b = df_mixed_S8b._append(data)

# %%
#newway
#nucleai

# %%
import seaborn as sns
#violin

# %%
#F0_vs_F10

# %%
#experiment 1
S3a_nucleai = df_nucleai_S3['mean_intensity']
S3a_cytoplasm = df_cytoplasm_S3['mean_intensity']

#S6a_nucleai
S3a_nucleai = S3a_nucleai.reset_index()
S3a_nucleai = S3a_nucleai['mean_intensity']

#S6a_cytoplasm
S3a_cytoplasm = S3a_cytoplasm.reset_index()
S3a_cytoplasm = S3a_cytoplasm['mean_intensity']

###

S6a_nucleai = df_nucleai_S6a['mean_intensity']
S6a_cytoplasm = df_cytoplasm_S6a['mean_intensity']

#S6a_nucleai
S6a_nucleai = S6a_nucleai.reset_index()
S6a_nucleai = S6a_nucleai['mean_intensity']

#S6a_cytoplasm
S6a_cytoplasm = S6a_cytoplasm.reset_index()
S6a_cytoplasm = S6a_cytoplasm['mean_intensity']

###

data = [S3a_nucleai, S3a_cytoplasm, S6a_nucleai, S6a_cytoplasm]
dat = pd.DataFrame({'WTB16F0 \nNucleai': pd.Series(S3a_nucleai), 'WTB16F0 \nCytoplasm': pd.Series(S3a_cytoplasm), 'WTB16F10 \nNucleai': pd.Series(S6a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S6a_cytoplasm)})


sns.set(font_scale = 1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 50)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat,   size=2, color="black").set(xlabel = 'Experiment 1', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S3a_nucleai = np.median(S3a_nucleai)
medians_S3a_cytoplasm = np.median(S3a_cytoplasm)

medians_S6a_nucleai = np.median(S6a_nucleai)
medians_S6a_cytoplasm = np.median(S6a_cytoplasm)


plt.annotate(round(medians_S3a_nucleai,2), xy=(0.1, 6.65),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S3a_cytoplasm,2), xy=(1.1, 4.51),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S6a_nucleai,2), xy=(2.1, 1.84),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S6a_cytoplasm,2), xy=(3.1, 1.44),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 1', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-164-7c751969e35a>:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#experiment 2
S4a_nucleai = df_nucleai_S4a['mean_intensity']
S4a_cytoplasm = df_cytoplasm_S4a['mean_intensity']

#S4a_nucleai
S4a_nucleai = S4a_nucleai.reset_index()
S4a_nucleai = S4a_nucleai['mean_intensity']

#S4a_cytoplasm
S4a_cytoplasm = S4a_cytoplasm.reset_index()
S4a_cytoplasm = S4a_cytoplasm['mean_intensity']

###

S7a_nucleai = df_nucleai_S7a['mean_intensity']
S7a_cytoplasm = df_cytoplasm_S7a['mean_intensity']

#S7a_nucleai
S7a_nucleai = S7a_nucleai.reset_index()
S7a_nucleai = S7a_nucleai['mean_intensity']

#S6a_cytoplasm
S7a_cytoplasm = S7a_cytoplasm.reset_index()
S7a_cytoplasm = S7a_cytoplasm['mean_intensity']

###

data = [S4a_nucleai, S4a_cytoplasm, S7a_nucleai, S7a_cytoplasm]
dat = pd.DataFrame({'WT \nNucleai': pd.Series(S4a_nucleai), 'WT \nCytoplasm': pd.Series(S4a_cytoplasm), 'WTB16F10 \nNucleai': pd.Series(S7a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S7a_cytoplasm)})


sns.set(font_scale = 1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 50)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat,   size=2,color="black").set(xlabel = 'Experiment 2', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S4a_nucleai = np.median(S4a_nucleai)
medians_S4a_cytoplasm = np.median(S4a_cytoplasm)

medians_S7a_nucleai = np.median(S7a_nucleai)
medians_S7a_cytoplasm = np.median(S7a_cytoplasm)


plt.annotate(round(medians_S4a_nucleai,2), xy=(0.1, 9.12),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S4a_cytoplasm,2), xy=(1.1, 4.29),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S7a_nucleai,2), xy=(2.1, 0.05),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S7a_cytoplasm,2), xy=(3.1, 0.05),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 2', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-165-0cfd21c0e157>:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#experiment 3
S5a_nucleai = df_nucleai_S5a['mean_intensity']
S5a_cytoplasm = df_cytoplasm_S5a['mean_intensity']

#S5a_nucleai
S5a_nucleai = S5a_nucleai.reset_index()
S5a_nucleai = S5a_nucleai['mean_intensity']

#S5a_cytoplasm
S5a_cytoplasm = S5a_cytoplasm.reset_index()
S5a_cytoplasm = S5a_cytoplasm['mean_intensity']

###

S8a_nucleai = df_nucleai_S8a['mean_intensity']
S8a_cytoplasm = df_cytoplasm_S8a['mean_intensity']

#S8a_nucleai
S8a_nucleai = S8a_nucleai.reset_index()
S8a_nucleai = S8a_nucleai['mean_intensity']

#S8a_cytoplasm
S8a_cytoplasm = S8a_cytoplasm.reset_index()
S8a_cytoplasm = S8a_cytoplasm['mean_intensity']

###

data = [S5a_nucleai, S5a_cytoplasm, S8a_nucleai, S8a_cytoplasm]
dat = pd.DataFrame({'WT \nNucleai': pd.Series(S5a_nucleai), 'WT \nCytoplasm': pd.Series(S5a_cytoplasm), 'WTB16F10 \nNucleai': pd.Series(S8a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S8a_cytoplasm)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 50)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat,   size=2,color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S5a_nucleai = np.median(S5a_nucleai)
medians_S5a_cytoplasm = np.median(S5a_cytoplasm)

medians_S8a_nucleai = np.median(S8a_nucleai)
medians_S8a_cytoplasm = np.median(S8a_cytoplasm)


plt.annotate(round(medians_S5a_nucleai,2), xy=(0.1, 5.41),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S5a_cytoplasm,2), xy=(1.1, 2.12),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S8a_nucleai,2), xy=(2.1, 1.86),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S8a_cytoplasm,2), xy=(3.1, 2.76),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 3', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-166-8292ed69d914>:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#experiment 1
S6a_nucleai = df_nucleai_S6a['mean_intensity']
S6a_cytoplasm = df_cytoplasm_S6a['mean_intensity']

#S6a_nucleai
S6a_nucleai = S6a_nucleai.reset_index()
S6a_nucleai = S6a_nucleai['mean_intensity']

#S6a_cytoplasm
S6a_cytoplasm = S6a_cytoplasm.reset_index()
S6a_cytoplasm = S6a_cytoplasm['mean_intensity']

###

S6b_nucleai = df_nucleai_S6b['mean_intensity']
S6b_cytoplasm = df_cytoplasm_S6b['mean_intensity']

#S6a_nucleai
S6b_nucleai = S6b_nucleai.reset_index()
S6b_nucleai = S6b_nucleai['mean_intensity']

#S6a_cytoplasm
S6b_cytoplasm = S6b_cytoplasm.reset_index()
S6b_cytoplasm = S6b_cytoplasm['mean_intensity']

###

data = [S6a_nucleai, S6a_cytoplasm, S6b_nucleai, S6b_cytoplasm]
dat = pd.DataFrame({'WTB16F10 \nNucleai': pd.Series(S6a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S6a_cytoplasm), 'K/O PITPNC1 \nNucleai': pd.Series(S6b_nucleai), 'K/O PITPNC1 \nCytoplasm': pd.Series(S6b_cytoplasm)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat,   size =2, color="black").set(xlabel = 'Experiment 1', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S6a_nucleai = np.median(S6a_nucleai)
medians_S6a_cytoplasm = np.median(S6a_cytoplasm)

medians_S6b_nucleai= np.median(S6b_nucleai)
medians_S6b_cytoplasm = np.median(S6b_cytoplasm)


plt.annotate(round(medians_S6a_nucleai,2), xy=(0.1, 1.84),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S6a_cytoplasm,2), xy=(1.1, 1.44),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S6b_nucleai,2), xy=(2.1, 3.34),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S6b_cytoplasm,2), xy=(3.1, 3.66),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 1', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-167-b1ec83b41b68>:37: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#experiment 2
S7a_nucleai = df_nucleai_S7a['mean_intensity']
S7a_cytoplasm = df_cytoplasm_S7a['mean_intensity']

#S7a_nucleai
S7a_nucleai = S7a_nucleai.reset_index()
S7a_nucleai = S7a_nucleai['mean_intensity']

#S7a_cytoplasm
S7a_cytoplasm = S7a_cytoplasm.reset_index()
S7a_cytoplasm = S7a_cytoplasm['mean_intensity']

####
S7b_nucleai = df_nucleai_S7b['mean_intensity']
S7b_cytoplasm = df_cytoplasm_S7b['mean_intensity']

#S7b_nucleai
S7b_nucleai = S7b_nucleai.reset_index()
S7b_nucleai = S7b_nucleai['mean_intensity']

#S7b_cytoplasm
S7b_cytoplasm = S7b_cytoplasm.reset_index()
S7b_cytoplasm = S7b_cytoplasm['mean_intensity']
####

data = [S7a_nucleai, S7a_cytoplasm, S7b_nucleai, S7b_cytoplasm]
dat = pd.DataFrame({'WTB16F10 \nNucleai': pd.Series(S7a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S7a_cytoplasm), 'K/O PITPNC1 \nNucleai': pd.Series(S7b_nucleai), 'K/O PITPNC1 \nCytoplasm': pd.Series(S7b_cytoplasm)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat,  size =2, color="black").set(xlabel = 'Experiment 2', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S7a_nucleai = np.median(S7a_nucleai)
medians_S7a_cytoplasm = np.median(S7a_cytoplasm)

medians_S7b_nucleai= np.median(S7b_nucleai)
medians_S7b_cytoplasm = np.median(S7b_cytoplasm)


plt.annotate(round(medians_S7a_nucleai,2), xy=(0.1, 0.05),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S7a_cytoplasm,2), xy=(1.1, 0.05),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S7b_nucleai,2), xy=(2.1, 5.87),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S7b_cytoplasm,2), xy=(3.1, 1.86),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 2', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-168-83634be800a7>:35: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#experiment 3
S8a_nucleai = df_nucleai_S8a['mean_intensity']
S8a_cytoplasm = df_cytoplasm_S8a['mean_intensity']

#S8a_nucleai
S8a_nucleai = S8a_nucleai.reset_index()
S8a_nucleai = S8a_nucleai['mean_intensity']

#S8a_cytoplasm
S8a_cytoplasm = S8a_cytoplasm.reset_index()
S8a_cytoplasm = S8a_cytoplasm['mean_intensity']

####
S8b_nucleai = df_nucleai_S8b['mean_intensity']
S8b_cytoplasm = df_cytoplasm_S8b['mean_intensity']

#S8b_nucleai
S8b_nucleai = S8b_nucleai.reset_index()
S8b_nucleai = S8b_nucleai['mean_intensity']

#S8b_cytoplasm
S8b_cytoplasm = S8b_cytoplasm.reset_index()
S8b_cytoplasm = S8b_cytoplasm['mean_intensity']
#####

data = [S8a_nucleai, S8a_cytoplasm,S8b_nucleai, S8b_cytoplasm]
dat = pd.DataFrame({'WTB16F10 \nNucleai': pd.Series(S8a_nucleai), 'WTB16F10 \nCytoplasm': pd.Series(S8a_cytoplasm),'K/O PITPNC1 \nNucleai': pd.Series(S8b_nucleai), 'K/O PITPNC1 \nCytoplasm': pd.Series(S8b_cytoplasm)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

#medians
medians_S8a_nucleai = np.median(S8a_nucleai)
medians_S8a_cytoplasm = np.median(S8a_cytoplasm)

medians_S8b_nucleai= np.median(S8b_nucleai)
medians_S8b_cytoplasm = np.median(S8b_cytoplasm)


plt.annotate(round(medians_S8a_nucleai,2), xy=(0.1, 1.86),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S8a_cytoplasm,2), xy=(1.1, 2.76),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S8b_nucleai,2), xy=(2.1, 0.12),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_S8b_cytoplasm,2), xy=(3.1, 0.59),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Experiment 3', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-169-fd3063252163>:36: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#separate experiments nuclei
data = [S6a_nucleai, S6b_nucleai,S7a_nucleai, S7b_nucleai, S8a_nucleai, S8b_nucleai]
dat = pd.DataFrame({'WTB16F10 \nExperiment 1': pd.Series(S6a_nucleai), 'K/O PITPNC1 \nExperiment 1': pd.Series(S6b_nucleai),'WTB16F10 \nExperiment 2': pd.Series(S7a_nucleai), 'K/O PITPNC1 \nExperiment 2': pd.Series(S7b_nucleai), 'WTB16F10 \nExperiment 3': pd.Series(S8a_nucleai), 'K/O PITPNC1 \nExperiment 3': pd.Series(S8b_nucleai)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(16,10)})
plt.ylim(-10, 35)
plt.hlines(y=4.0, xmin=-1.00, xmax=6, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=6, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=6, colors='purple' ,  alpha =0.7,ls=':')

ax = sns.violinplot(data=dat, palette="flare", linewidth = 2)

S6a_nucleai_pvalue = S6a_nucleai[(S6a_nucleai > 4) & (S6a_nucleai <= S6a_nucleai.quantile(0.75))]
S6b_nucleai_pvalue = S6b_nucleai[(S6b_nucleai > 4) & (S6b_nucleai <= S6b_nucleai.quantile(0.75))]

S7a_nucleai_pvalue = S7a_nucleai[(S7a_nucleai > 4) & (S7a_nucleai <= S7a_nucleai.quantile(0.75))]
S7b_nucleai_pvalue = S7b_nucleai[(S7b_nucleai > 4) & (S7b_nucleai <= S7b_nucleai.quantile(0.75))]

S8a_nucleai_pvalue = S8a_nucleai[(S8a_nucleai > 4) & (S8a_nucleai <= S8a_nucleai.quantile(0.75))]
S8b_nucleai_pvalue = S8b_nucleai[(S8b_nucleai > 4) & (S8b_nucleai <= S8b_nucleai.quantile(0.75))]

#short range
U1, p1 = mannwhitneyu(S6a_nucleai_pvalue, S6b_nucleai_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = ns" , xy=(0.7, 33),weight='bold')

#whole range
U1, p2 = mannwhitneyu(S6a_nucleai, S6b_nucleai, method="exact")
ax.annotate("p = ns", xy=(0.7, 31),weight='bold')

#short range
#U1, p1 = mannwhitneyu(S7a_nucleai_pvalue, S7b_nucleai_pvalue, method="exact")
ax.annotate("p_iqr = None" , xy=(2.7, 33),weight='bold')
#ax.annotate("p = %s" % (round(p1,3)) , xy=(2.7, 33),weight='bold')

#whole range
U1, p2 = mannwhitneyu(S7a_nucleai, S7b_nucleai, method="exact")
ax.annotate("p = ****", xy=(2.7, 31),weight='bold')
#p2 = 1.7197229138342682e-07

#short range
#U1, p1 = mannwhitneyu(S8a_nucleai_pvalue, S8b_nucleai_pvalue, method="exact")
ax.annotate("p_iqr = None" , xy=(4.4, 33),weight='bold')
#ax.annotate("p = %s" % (round(p1,3)) , xy=(4.7, 33),weight='bold')

#whole range
U1, p2 = mannwhitneyu(S8a_nucleai, S8b_nucleai, method="exact")
ax.annotate("p = * " , xy=(4.4, 31),weight='bold')
#p2 = 0.04406377842344013

for violin in ax.collections:
    violin.set_alpha(0.85)

sns.stripplot(data=dat,   size =1, color="black").set( ylabel='% FRET Efficiency (Ef)')


q75, q50, q25 = np.percentile(S6a_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(0.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(0.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(0.1, round(q25,2)-0.2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S6b_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(1.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(1.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(1.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S7a_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(2.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(2.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(2.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S7b_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(3.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(3.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(3.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S8a_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(4.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(4.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(4.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S8b_nucleai, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(5.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(5.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(5.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');

# %%
p2
# Out:
# 0.04406377842344013

# %%
#separate experiments cyto
data = [S6a_cytoplasm, S6b_cytoplasm,S7a_cytoplasm, S7b_cytoplasm, S8a_cytoplasm, S8b_cytoplasm]
dat = pd.DataFrame({'WTB16F10 \nExperiment 1': pd.Series(S6a_cytoplasm), 'K/O PITPNC1 \nExperiment 1': pd.Series(S6b_cytoplasm),'WTB16F10 \nExperiment 2': pd.Series(S7a_cytoplasm), 'K/O PITPNC1 \nExperiment 2': pd.Series(S7b_cytoplasm), 'WTB16F10 \nExperiment 3': pd.Series(S8a_cytoplasm), 'K/O PITPNC1 \nExperiment 3': pd.Series(S8b_cytoplasm)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(16,10)})
plt.ylim(-10, 35)
plt.hlines(y=4, xmin=-1.00, xmax=6, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=6, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=6, colors='purple' ,  alpha =0.7,ls=':')

ax = sns.violinplot(data=dat, palette="flare", linewidth = 2)

S6a_cytoplasm_pvalue = S6a_cytoplasm[(S6a_cytoplasm > 4) & (S6a_cytoplasm <= S6a_cytoplasm.quantile(0.75))]
S6b_cytoplasm_pvalue = S6b_cytoplasm[(S6b_cytoplasm > 4) & (S6b_cytoplasm <= S6b_cytoplasm.quantile(0.75))]

S7a_cytoplasm_pvalue = S7a_cytoplasm[(S7a_cytoplasm > 4) & (S7a_cytoplasm <= S7a_cytoplasm.quantile(0.75))]
S7b_cytoplasm_pvalue = S7b_cytoplasm[(S7b_cytoplasm > 4) & (S7b_cytoplasm <= S7b_cytoplasm.quantile(0.75))]

S8a_cytoplasm_pvalue = S8a_cytoplasm[(S8a_cytoplasm > 4) & (S8a_cytoplasm <= S8a_cytoplasm.quantile(0.75))]
S8b_cytoplasm_pvalue = S8b_cytoplasm[(S8b_cytoplasm > 4) & (S8b_cytoplasm <= S8b_cytoplasm.quantile(0.75))]

#short range
U1, p1 = mannwhitneyu(S6a_cytoplasm_pvalue, S6b_cytoplasm_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = ns" , xy=(0.7, 33),weight='bold')
#p2 = 0.5714285714285714

# #whole range
U1, p2 = mannwhitneyu(S6a_cytoplasm, S6b_cytoplasm, method="exact")
ax.annotate("p = * ", xy=(0.7, 31),weight='bold')
#p2 = 0.03484583620162381

#short range
#U1, p1 = mannwhitneyu(S7a_cytoplasm_pvalue, S7b_cytoplasm_pvalue, method="exact")
#ax.annotate("None" , xy=(0.7, 30),weight='bold')
ax.annotate("p_iqr = None" , xy=(2.7, 33),weight='bold')
#p2 =

# #whole range
U1, p2 = mannwhitneyu(S7a_cytoplasm, S7b_cytoplasm, method="exact")
ax.annotate("p = **** ", xy=(2.7, 31),weight='bold')
#p2 = 3.0047693787042293e-09

#short range
#U1, p1 = mannwhitneyu(S8a_cytoplasm_pvalue, S8b_cytoplasm_pvalue, method="exact")
#ax.annotate("None" , xy=(4.4, 30),weight='bold')
ax.annotate("p_iqr = None" , xy=(4.4, 33),weight='bold')
#p2 =

# # #whole range
U1, p2 = mannwhitneyu(S8a_cytoplasm, S8b_cytoplasm, method="exact")
ax.annotate("p = ns", xy=(4.4, 31),weight='bold')
#p2 = 0.294514223080258

for violin in ax.collections:
    violin.set_alpha(0.85)

sns.stripplot(data=dat,   size =1, color="black").set( ylabel='% FRET Efficiency (Ef)')


q75, q50, q25 = np.percentile(S6a_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(0.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(0.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(0.1, round(q25,2)-0.2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S6b_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(1.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(1.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(1.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S7a_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(2.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(2.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(2.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S7b_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(3.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(3.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(3.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S8a_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(4.1, round(q75,2)),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(4.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(4.1, round(q25,2)),fontsize = 16, weight='bold', color='purple')

q75, q50, q25 = np.percentile(S8b_cytoplasm, [75 , 50, 25])
plt.annotate(round(q75,2), xy=(5.1, round(q75,2)+2),fontsize = 16, weight='bold', color='purple')
plt.annotate(round(q50,2), xy=(5.1, round(q50,2)),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(q25,2), xy=(5.1, round(q25,2)-2),fontsize = 16, weight='bold', color='purple')

plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');

# %%
p2
# Out:
# 0.294514223080258

# %%
#WTB16F0_WTB16F10
S8a_nucleai = df_nucleai_S8a['mean_intensity']
S8a_cytoplasm = df_cytoplasm_S8a['mean_intensity']

#S6a_nucleai
S8a_nucleai = S8a_nucleai.reset_index()
S8a_nucleai = S8a_nucleai['mean_intensity']

#S6a_cytoplasm
S8a_cytoplasm = S8a_cytoplasm.reset_index()
S8a_cytoplasm = S8a_cytoplasm['mean_intensity']

data = [S8a_nucleai, S8a_cytoplasm]
dat = pd.DataFrame({'Nucleai': pd.Series(S8a_nucleai), 'Cytoplasm': pd.Series(S8a_cytoplasm)})


sns.set(style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 30)
plt.hlines(y=3.5, xmin=-1.00, xmax=2, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=2, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=2, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
sns.stripplot(data=dat,  color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')
# Out:
# <ipython-input-174-b513787e51b8>:23: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')
# [Text(0.5, 0, 'Experiment 3'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#nucleai

# %%
S3a = df_nucleai_S3['mean_intensity']
S6a = df_nucleai_S6a['mean_intensity']

S4a = df_nucleai_S4a['mean_intensity']
S7a = df_nucleai_S7a['mean_intensity']

S5a = df_nucleai_S5a['mean_intensity']
S8a = df_nucleai_S8a['mean_intensity']

#S3a
S3a = S3a.reset_index()
S3a = S3a['mean_intensity']

#S6a
S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

#S4a
S4a = S4a.reset_index()
S4a = S4a['mean_intensity']

#S7a
S7a = S7a.reset_index()
S7a = S7a['mean_intensity']

#S5a
S5a = S5a.reset_index()
S5a = S5a['mean_intensity']

#S8a
S8a = S8a.reset_index()
S8a = S8a['mean_intensity']

data = [S3a, S6a, S4a, S7a, S5a, S8a]
dat = pd.DataFrame({'S3a': pd.Series(S3a), 'S6a': pd.Series(S6a),'S4a': pd.Series(S4a), 'S7a': pd.Series(S7a),'S5a': pd.Series(S5a), 'S8a': pd.Series(S8a)})

sns.boxplot(data=dat,  palette='flare').set(xlabel = 'Nucleai', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Nucleai'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#cyto
S3a = df_cytoplasm_S3['mean_intensity']
S6a = df_cytoplasm_S6a['mean_intensity']

S4a = df_cytoplasm_S4a['mean_intensity']
S7a = df_cytoplasm_S7a['mean_intensity']

S5a = df_cytoplasm_S5a['mean_intensity']
S8a = df_cytoplasm_S8a['mean_intensity']

#S3a
S3a = S3a.reset_index()
S3a = S3a['mean_intensity']

#S6a
S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

#S4a
S4a = S4a.reset_index()
S4a = S4a['mean_intensity']

#S7a
S7a = S7a.reset_index()
S7a = S7a['mean_intensity']

#S5a
S5a = S5a.reset_index()
S5a = S5a['mean_intensity']

#S8a
S8a = S8a.reset_index()
S8a = S8a['mean_intensity']

data = [S3a, S6a, S4a, S7a, S5a, S8a]
dat = pd.DataFrame({'S3a': pd.Series(S3a), 'S6a': pd.Series(S6a),'S4a': pd.Series(S4a), 'S7a': pd.Series(S7a),'S5a': pd.Series(S5a), 'S8a': pd.Series(S8a)})

sns.boxplot(data=dat,  palette='dark:#5A9_r').set(xlabel = 'Cytoplasm', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Cytoplasm'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#mixed

# %%
S3a = df_mixed_S3['mean_intensity']
S6a = df_mixed_S6a['mean_intensity']

S4a = df_mixed_S4a['mean_intensity']
S7a = df_mixed_S7a['mean_intensity']

S5a = df_mixed_S5a['mean_intensity']
S8a = df_mixed_S8a['mean_intensity']

#S3a
S3a = S3a.reset_index()
S3a = S3a['mean_intensity']

#S6a
S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

#S4a
S4a = S4a.reset_index()
S4a = S4a['mean_intensity']

#S7a
S7a = S7a.reset_index()
S7a = S7a['mean_intensity']

#S5a
S5a = S5a.reset_index()
S5a = S5a['mean_intensity']

#S8a
S8a = S8a.reset_index()
S8a = S8a['mean_intensity']

data = [S3a, S6a, S4a, S7a, S5a, S8a]
dat = pd.DataFrame({'S3a': pd.Series(S3a), 'S6a': pd.Series(S6a),'S4a': pd.Series(S4a), 'S7a': pd.Series(S7a),'S5a': pd.Series(S5a), 'S8a': pd.Series(S8a)})

sns.boxplot(data=dat,  palette='ch:s=.25,rot=-.25').set(xlabel = 'Mixed', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Mixed'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
###

# %%
S6a = df_nucleai_S6a['mean_intensity']
S6b = df_nucleai_S6b['mean_intensity']

S7a = df_nucleai_S7a['mean_intensity']
S7b = df_nucleai_S7b['mean_intensity']

S8a = df_nucleai_S8a['mean_intensity']
S8b = df_nucleai_S8b['mean_intensity']

S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

S6b = S6b.reset_index()
S6b = S6b['mean_intensity']

S7a = S7a.reset_index()
S7a = S7a['mean_intensity']
S7b = S7b.reset_index()
S7b = S7b['mean_intensity']

S8a = S8a.reset_index()
S8a = S8a['mean_intensity']
S8b = S8b.reset_index()
S8b = S8b['mean_intensity']

data = [S6a, S6b, S7a, S7b, S8a, S8b]
dat = pd.DataFrame({'S6a': pd.Series(S6a), 'S6b': pd.Series(S6b),'S7a': pd.Series(S7a), 'S7b': pd.Series(S7b),'S8a': pd.Series(S8a), 'S8b': pd.Series(S8b)})

sns.boxplot(data=dat,  palette='flare').set(xlabel = 'Nucleai', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Nucleai'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#cyto

# %%
S6a = df_cytoplasm_S6a['mean_intensity']
S6b = df_cytoplasm_S6b['mean_intensity']

S7a = df_cytoplasm_S7a['mean_intensity']
S7b = df_cytoplasm_S7b['mean_intensity']

S8a = df_cytoplasm_S8a['mean_intensity']
S8b = df_cytoplasm_S8b['mean_intensity']

S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

S6b = S6b.reset_index()
S6b = S6b['mean_intensity']

S7a = S7a.reset_index()
S7a = S7a['mean_intensity']
S7b = S7b.reset_index()
S7b = S7b['mean_intensity']

S8a = S8a.reset_index()
S8a = S8a['mean_intensity']
S8b = S8b.reset_index()
S8b = S8b['mean_intensity']

data = [S6a, S6b, S7a, S7b, S8a, S8b]
dat = pd.DataFrame({'S6a': pd.Series(S6a), 'S6b': pd.Series(S6b),'S7a': pd.Series(S7a), 'S7b': pd.Series(S7b),'S8a': pd.Series(S8a), 'S8b': pd.Series(S8b)})

sns.boxplot(data=dat, palette='dark:#5A9_r').set(xlabel = 'Cytoplasm', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Cytoplasm'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#mixed
S6a = df_mixed_S6a['mean_intensity']
S6b = df_mixed_S6b['mean_intensity']

S7a = df_mixed_S7a['mean_intensity']
S7b = df_mixed_S7b['mean_intensity']

S8a = df_mixed_S8a['mean_intensity']
S8b = df_mixed_S8b['mean_intensity']

S6a = S6a.reset_index()
S6a = S6a['mean_intensity']

S6b = S6b.reset_index()
S6b = S6b['mean_intensity']

S7a = S7a.reset_index()
S7a = S7a['mean_intensity']
S7b = S7b.reset_index()
S7b = S7b['mean_intensity']

S8a = S8a.reset_index()
S8a = S8a['mean_intensity']
S8b = S8b.reset_index()
S8b = S8b['mean_intensity']

data = [S6a, S6b, S7a, S7b, S8a, S8b]
dat = pd.DataFrame({'S6a': pd.Series(S6a), 'S6b': pd.Series(S6b),'S7a': pd.Series(S7a), 'S7b': pd.Series(S7b),'S8a': pd.Series(S8a), 'S8b': pd.Series(S8b)})

sns.boxplot(data=dat, palette='ch:s=.25,rot=-.25').set(xlabel = 'Mixed', ylabel='% FRET Efficiency (Ef)')
# Out:
# [Text(0.5, 0, 'Mixed'), Text(0, 0.5, '% FRET Efficiency (Ef)')]

# %%
#nucleai

# %%
# #0_3.5
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 0)&(df_nucleai_S8a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8b = df_nucleai_S8b[(df_nucleai_S8b['mean_intensity'] > 0)&(df_nucleai_S8b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.43, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.45, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.4))
# plt.annotate(str(round(mu,2)),xy=(mu,0.42))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5..10
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 3.5)&(df_nucleai_S8a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8b = df_nucleai_S8b[(df_nucleai_S8b['mean_intensity'] > 3.5)&(df_nucleai_S8b['mean_intensity'] < 10)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=10, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.165, colors='crimson' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.15))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10..20
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 10)&(df_nucleai_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_nucleai_S8b[(df_nucleai_S8b['mean_intensity'] > 10)&(df_nucleai_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# # plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# # plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5..20
# hist_S8a = df_nucleai_S8a[(df_nucleai_S8a['mean_intensity'] > 3.5)&(df_nucleai_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_nucleai_S8b[(df_nucleai_S8b['mean_intensity'] > 3.5)&(df_nucleai_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.1, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=3.5, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# #plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#cyto

# %%
#0_3.5
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 0)&(df_cytoplasm_S8a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8b = df_cytoplasm_S8b[(df_cytoplasm_S8b['mean_intensity'] > 0)&(df_cytoplasm_S8b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.98, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.334, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.9))
# plt.annotate(str(round(mu,2)),xy=(mu,0.3))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 3.5)&(df_cytoplasm_S8a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8b = df_cytoplasm_S8b[(df_cytoplasm_S8b['mean_intensity'] > 3.5)&(df_cytoplasm_S8b['mean_intensity'] < 10)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.18, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.46, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.18))
# plt.annotate(str(round(mu,2)),xy=(mu,0.45))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 10)&(df_cytoplasm_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_cytoplasm_S8b[(df_cytoplasm_S8b['mean_intensity'] > 10)&(df_cytoplasm_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# # plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# # plt.vlines(x=mu, ymin=-0.00, ymax=0.55, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')

# # plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# # plt.annotate(str(round(mu,2)),xy=(mu,0.5))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S8a = df_cytoplasm_S8a[(df_cytoplasm_S8a['mean_intensity'] > 3.5)&(df_cytoplasm_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_cytoplasm_S8b[(df_cytoplasm_S8b['mean_intensity'] > 3.5)&(df_cytoplasm_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.122, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.09, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.1))
# plt.annotate(str(round(mu,2)),xy=(mu,0.09))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
#mixed

# %%
#0_3.5
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 0)&(df_mixed_S8a['mean_intensity'] < 3.5)]['mean_intensity']
# hist_S8b = df_mixed_S8b[(df_mixed_S8b['mean_intensity'] > 0)&(df_mixed_S8b['mean_intensity'] < 3.5)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(0, 3.5, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.54, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.41, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.4))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_10
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 3.5)&(df_mixed_S8a['mean_intensity'] < 10)]['mean_intensity']
# hist_S8b = df_mixed_S8b[(df_mixed_S8b['mean_intensity'] > 3.5)&(df_mixed_S8b['mean_intensity'] < 10)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 10, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.27, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.25, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.25))
# plt.annotate(str(round(mu,2)),xy=(mu,0.22))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #10_20
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 10)&(df_mixed_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_mixed_S8b[(df_mixed_S8b['mean_intensity'] > 10)&(df_mixed_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(10, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# #plt.vlines(x=mu2, ymin=-0.00, ymax=0.44, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.105, colors='crimson' , alpha = 0.3, ls=':')
# plt.hlines(y=0, xmin=10, xmax=20, colors='blue' , alpha = 0.3, ls=':')


# #plt.annotate(str(round(mu2,2)),xy=(mu2,0.48))
# plt.annotate(str(round(mu,2)),xy=(mu,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
# #3.5_20
# hist_S8a = df_mixed_S8a[(df_mixed_S8a['mean_intensity'] > 3.5)&(df_mixed_S8a['mean_intensity'] < 20)]['mean_intensity']
# hist_S8b = df_mixed_S8b[(df_mixed_S8b['mean_intensity'] > 3.5)&(df_mixed_S8b['mean_intensity'] < 20)]['mean_intensity']

# hist_S8a = hist_S8a.sort_values()
# hist_S8b = hist_S8b.sort_values()

# %%
# mu = np.mean(hist_S8a)
# variance = np.var(hist_S8a)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu, sigma), color = 'crimson', alpha = 0.3)

# mu2 = np.mean(hist_S8b)
# variance = np.var(hist_S8b)
# sigma = math.sqrt(variance)
# x = np.linspace(3.5, 20, 100)
# plt.plot(x, stats.norm.pdf(x, mu2, sigma), color = 'blue', alpha = 0.3)

# plt.vlines(x=mu2, ymin=-0.00, ymax=0.27, colors='blue' , alpha = 0.3, ls=':')
# plt.vlines(x=mu, ymin=-0.00, ymax=0.09, colors='crimson' , alpha = 0.3, ls=':')

# plt.annotate(str(round(mu2,2)),xy=(mu2,0.2))
# plt.annotate(str(round(mu,2)),xy=(mu,0.1))

# plt.xlabel('FRET-efficiency (%)')
# plt.ylabel('Probability Density')

# plt.show()

# %%
Nuclei_F10 = S6a_nucleai
Nuclei_F10
# Out:
# 0      6.155097
# 1     16.786331
# 2      2.173394
# 3     17.482673
# 4     16.026209
# 5     14.754102
# 6     13.669763
# 7      6.357218
# 8      5.274522
# 9      5.248703
# 10     4.590515
# 11     4.172282
# 12     3.554621
# 13     3.362734
# 14     1.982002
# 15     1.957482
# 16     1.350952
# 17     0.641141
# 18     4.304055
# 19     3.917347
# 20     1.463501
# 21     0.897714
# 22     0.097816
# 23     0.077658
# 24     0.058703
# 25     0.048972
# 26     0.000000
# 27     0.000000
# 28     1.729977
# 29     1.120573
# 30     0.693825
# 31     0.247458
# 32     0.214660
# 33     0.000000
# 34     0.000000
# 35     0.000000
# 36     0.000000
# 37    10.066322
# 38     6.853950
# 39     0.556490
# 40     0.362847
# 41     0.130000
# 42     0.000000
# 43     0.595732
# 44     0.231257
# 45     0.046625
# 46    22.663060
# 47    20.052264
# 48    19.941420
# 49    10.672535
# 50    10.330000
# 51     9.656785
# 52     4.200000
# 53     0.000000
# ...

# %%
s1 = S6a_nucleai._append(S7a_nucleai, ignore_index=True)
Nuclei_F10 = s1._append(S8a_nucleai, ignore_index=True)

s2 = S6b_nucleai._append(S7b_nucleai, ignore_index=True)
Nuclei_Knockout= s2._append(S8b_nucleai, ignore_index=True)

# %%
#F10_vs_K/O

data = [Nuclei_F10, Nuclei_Knockout]
dat = pd.DataFrame({'WTB16F10': pd.Series(Nuclei_F10), 'K/O PITPNC1': pd.Series(Nuclei_Knockout)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_Nuclei_F10= np.median(Nuclei_F10)
medians_Nuclei_Knockout = np.median(Nuclei_Knockout)

# medians_S8b_nucleai= np.median(S8b_nucleai)
# medians_S8b_cytoplasm = np.median(S8b_cytoplasm)


plt.annotate(round(medians_Nuclei_F10,2), xy=(0.1, 0.77),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_Nuclei_Knockout,2), xy=(1.1, 3.08),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_nucleai,2), xy=(2.1, 0.12),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_cytoplasm,2), xy=(3.1, 0.59),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Nuclei', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-214-d23c0309a5b3>:13: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
s3 = S6a_cytoplasm._append(S7a_cytoplasm, ignore_index=True)
Cytoplasm_F10 = s3._append(S8a_cytoplasm, ignore_index=True)

s4 = S6b_cytoplasm._append(S7b_cytoplasm, ignore_index=True)
Cytoplasm_Knockout= s4._append(S8b_cytoplasm, ignore_index=True)

# %%
#F10_vs_K/O

data = [Cytoplasm_F10, Cytoplasm_Knockout]
dat = pd.DataFrame({'WTB16F10': pd.Series(Cytoplasm_F10), 'K/O PITPNC1': pd.Series(Cytoplasm_Knockout)})


sns.set(font_scale=1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-10, 35)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')

sns.violinplot(data=dat,  scale='count', palette='flare')
#sns.stripplot(data=dat, size =2, color="black").set(xlabel = 'Experiment 3', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_Cytoplasm_F10 = np.median(Cytoplasm_F10)
medians_Cytoplasm_Knockout = np.median(Cytoplasm_Knockout)

# medians_S8b_nucleai= np.median(S8b_nucleai)
# medians_S8b_cytoplasm = np.median(S8b_cytoplasm)


plt.annotate(round(medians_Cytoplasm_F10,2), xy=(0.1, 0.56),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_Cytoplasm_Knockout,2), xy=(1.1, 2.26),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_nucleai,2), xy=(2.1, 0.12),fontsize = 16, weight='bold', color='darkblue')
# plt.annotate(round(medians_S8b_cytoplasm,2), xy=(3.1, 0.59),fontsize = 16, weight='bold', color='darkblue')

sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Cytoplasm', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-216-59b42f63d7a6>:13: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
#Threonine -vs Serine

# %%
#Slide 1


#well 1

data_path = '/content/drive/MyDrive/24-01-23 Results/Slide 1 (1)/well 1 (1)/Results'
os.chdir(data_path)
files = os.listdir(data_path)

#nucleai
nucleai_scv_F0_s1_w1 = [f for f in files if 'nucleai' in f]
df_nucleai_F0_s1_w1 = pd.DataFrame()
for f in nucleai_scv_F0_s1_w1:
    data = pd.read_csv(f)
    df_nucleai_F0_s1_w1 = df_nucleai_F0_s1_w1._append(data)

#cytoplasm
cytoplasm_scv_F0_s1_w1 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_F0_s1_w1 = pd.DataFrame()
for f in cytoplasm_scv_F0_s1_w1:
    data = pd.read_csv(f)
    df_cytoplasm_F0_s1_w1 = df_cytoplasm_F0_s1_w1._append(data)

#mixed
mixed_scv_F0_s1_w1 = [f for f in files if 'mixed' in f]
df_mixed_F0_s1_w1 = pd.DataFrame()
for f in mixed_scv_F0_s1_w1:
    data = pd.read_csv(f)
    df_mixed_F0_s1_w1 = df_mixed_F0_s1_w1._append(data)

#well 3

data_path = '/content/drive/MyDrive/24-01-23 Results/Slide 1 (1)/well 3 (1)/Results'
os.chdir(data_path)
files = os.listdir(data_path)

#nucleai
nucleai_scv_F0_s1_w3 = [f for f in files if 'nucleai' in f]
df_nucleai_F0_s1_w3 = pd.DataFrame()
for f in nucleai_scv_F0_s1_w3:
    data = pd.read_csv(f)
    df_nucleai_F0_s1_w3 = df_nucleai_F0_s1_w3._append(data)

#cytoplasm
cytoplasm_scv_F0_s1_w3 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_F0_s1_w3 = pd.DataFrame()
for f in cytoplasm_scv_F0_s1_w3:
    data = pd.read_csv(f)
    df_cytoplasm_F0_s1_w3 = df_cytoplasm_F0_s1_w3._append(data)

#mixed
mixed_scv_F0_s1_w3 = [f for f in files if 'mixed' in f]
df_mixed_F0_s1_w3 = pd.DataFrame()
for f in mixed_scv_F0_s1_w3:
    data = pd.read_csv(f)
    df_mixed_F0_s1_w3 = df_mixed_F0_s1_w3._append(data)

#well 4

data_path = '/content/drive/MyDrive/24-01-23 Results/Slide 1 (1)/well 4 (1)/Results'
os.chdir(data_path)
files = os.listdir(data_path)

#nucleai
nucleai_scv_F0_s1_w4 = [f for f in files if 'nucleai' in f]
df_nucleai_F0_s1_w4 = pd.DataFrame()
for f in nucleai_scv_F0_s1_w4:
    data = pd.read_csv(f)
    df_nucleai_F0_s1_w4 = df_nucleai_F0_s1_w4._append(data)

#cytoplasm
cytoplasm_scv_F0_s1_w4 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_F0_s1_w4 = pd.DataFrame()
for f in cytoplasm_scv_F0_s1_w4:
    data = pd.read_csv(f)
    df_cytoplasm_F0_s1_w4 = df_cytoplasm_F0_s1_w4._append(data)

#mixed
mixed_scv_F0_s1_w4 = [f for f in files if 'mixed' in f]
df_mixed_F0_s1_w4 = pd.DataFrame()
for f in mixed_scv_F0_s1_w4:
    data = pd.read_csv(f)
    df_mixed_F0_s1_w4 = df_mixed_F0_s1_w4._append(data)


#Slide 2


#well 1

data_path = '/content/drive/MyDrive/24-01-23 Results/Slide 2 (1)/well 1 (1)/Results'
os.chdir(data_path)
files = os.listdir(data_path)

#nucleai
nucleai_scv_F0_s2_w1 = [f for f in files if 'nucleai' in f]
df_nucleai_F0_s2_w1 = pd.DataFrame()
for f in nucleai_scv_F0_s2_w1:
    data = pd.read_csv(f)
    df_nucleai_F0_s2_w1 = df_nucleai_F0_s2_w1._append(data)

#cytoplasm
cytoplasm_scv_F0_s2_w1 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_F0_s2_w1 = pd.DataFrame()
for f in cytoplasm_scv_F0_s2_w1:
    data = pd.read_csv(f)
    df_cytoplasm_F0_s2_w1 = df_cytoplasm_F0_s2_w1._append(data)

#mixed
mixed_scv_F0_s2_w1 = [f for f in files if 'mixed' in f]
df_mixed_F0_s2_w1 = pd.DataFrame()
for f in mixed_scv_F0_s2_w1:
    data = pd.read_csv(f)
    df_mixed_F0_s2_w1 = df_mixed_F0_s2_w1._append(data)


#well 3

data_path = '/content/drive/MyDrive/24-01-23 Results/Slide 2 (1)/well 3 (1)/Results'
os.chdir(data_path)
files = os.listdir(data_path)

#nucleai
nucleai_scv_F0_s2_w3 = [f for f in files if 'nucleai' in f]
df_nucleai_F0_s2_w3 = pd.DataFrame()
for f in nucleai_scv_F0_s2_w3:
    data = pd.read_csv(f)
    df_nucleai_F0_s2_w3 = df_nucleai_F0_s2_w3._append(data)

#cytoplasm
cytoplasm_scv_F0_s2_w3 = [f for f in files if 'cytoplasm' in f]
df_cytoplasm_F0_s2_w3 = pd.DataFrame()
for f in cytoplasm_scv_F0_s2_w3:
    data = pd.read_csv(f)
    df_cytoplasm_F0_s2_w3 = df_cytoplasm_F0_s2_w3._append(data)

#mixed
mixed_scv_F0_s2_w3 = [f for f in files if 'mixed' in f]
df_mixed_F0_s2_w3 = pd.DataFrame()
for f in mixed_scv_F0_s2_w3:
    data = pd.read_csv(f)
    df_mixed_F0_s2_w3 = df_mixed_F0_s2_w3._append(data)

# %%
#append

F0_nucleus = pd.DataFrame()
F0_nucleus = F0_nucleus._append(df_nucleai_F0_s1_w1,  ignore_index=True)
F0_nucleus = F0_nucleus._append(df_nucleai_F0_s2_w1,  ignore_index=True)
F0_nucleus = F0_nucleus.reset_index()
F0_nucleus = F0_nucleus['mean_intensity']
#F0_nucleus = df_nucleai_F0_s1_w1 + df_nucleai_F0_s2_w1


F0_cytoplasm = pd.DataFrame()
F0_cytoplasm = F0_cytoplasm._append(df_cytoplasm_F0_s1_w1,  ignore_index=True)
F0_cytoplasm = F0_cytoplasm._append(df_cytoplasm_F0_s2_w1,  ignore_index=True)
F0_cytoplasm = F0_cytoplasm.reset_index()
F0_cytoplasm = F0_cytoplasm['mean_intensity']
#F0_cytoplasm = df_cytoplasm_F0_s1_w1 + df_cytoplasm_F0_s2_w1

F0_mixed = pd.DataFrame()
F0_mixed = F0_mixed._append(df_mixed_F0_s1_w1,  ignore_index=True)
F0_mixed = F0_mixed._append(df_mixed_F0_s2_w1,  ignore_index=True)
F0_mixed = F0_mixed.reset_index()
F0_mixed = F0_mixed['mean_intensity']
#F0_mixed = df_mixed_F0_s1_w1 + df_mixed_F0_s2_w1

T95C_nucleus = pd.DataFrame()
T95C_nucleus = T95C_nucleus._append(df_nucleai_F0_s1_w3,  ignore_index=True)
T95C_nucleus = T95C_nucleus._append(df_nucleai_F0_s2_w3,  ignore_index=True)
T95C_nucleus = T95C_nucleus.reset_index()
T95C_nucleus = T95C_nucleus['mean_intensity']
#T95C_nucleus = df_nucleai_F0_s1_w3 + df_nucleai_F0_s2_w3

T95c_cytoplasm = pd.DataFrame()
T95c_cytoplasm = T95c_cytoplasm._append(df_cytoplasm_F0_s1_w3,  ignore_index=True)
T95c_cytoplasm = T95c_cytoplasm._append(df_cytoplasm_F0_s2_w3,  ignore_index=True)
T95c_cytoplasm = T95c_cytoplasm.reset_index()
T95c_cytoplasm = T95c_cytoplasm['mean_intensity']
#T95c_cytoplasm = df_cytoplasm_F0_s1_w3 + df_cytoplasm_F0_s2_w3

T95c_mixed = pd.DataFrame()
T95c_mixed = T95c_mixed._append(df_mixed_F0_s1_w3,  ignore_index=True)
T95c_mixed = T95c_mixed._append(df_mixed_F0_s2_w3,  ignore_index=True)
T95c_mixed = T95c_mixed.reset_index()
T95c_mixed = T95c_mixed['mean_intensity']
#T95c_mixed = df_mixed_F0_s1_w3 + df_mixed_F0_s2_w3


T58E_nucleus = pd.DataFrame()
T58E_nucleus = T58E_nucleus._append(df_nucleai_F0_s1_w4,  ignore_index=True)
T58E_nucleus = T58E_nucleus.reset_index()
T58E_nucleus = T58E_nucleus['mean_intensity']
#T58E_nucleus = df_nucleai_F0_s1_w4

T58E_cytoplasm = pd.DataFrame()
T58E_cytoplasm = T58E_cytoplasm._append(df_cytoplasm_F0_s1_w4,  ignore_index=True)
T58E_cytoplasm = T58E_cytoplasm.reset_index()
T58E_cytoplasm = T58E_cytoplasm['mean_intensity']
#T58E_cytoplasm = df_cytoplasm_F0_s1_w4

T58E_mixed = pd.DataFrame()
T58E_mixed = T58E_mixed._append(df_mixed_F0_s1_w4,  ignore_index=True)
T58E_mixed = T58E_mixed.reset_index()
T58E_mixed = T58E_mixed['mean_intensity']
#T58E_mixed = df_mixed_F0_s1_w4

# %%
# #nucleus

data = [F0_nucleus, T95C_nucleus, T58E_nucleus]
dat = pd.DataFrame({'WTB16F0': pd.Series(F0_nucleus), 'T95C': pd.Series(T95C_nucleus), 'T58E': pd.Series(T58E_nucleus)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-5, 15)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
sns.stripplot(data=dat,   size =2, color="black").set(xlabel = 'Experiment 1', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_F0_nucleus = np.median(F0_nucleus)
medians_T95C_nucleus = np.median(T95C_nucleus)
medians_T58E_nucleus = np.median(T58E_nucleus)



plt.annotate(round(medians_F0_nucleus,2), xy=(0.1, 0.51),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T95C_nucleus,2), xy=(1.1, 2.47),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T58E_nucleus,2), xy=(2.1, 1.5),fontsize = 16, weight='bold', color='darkblue')

# sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Nuclei', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-220-8e5b08e9c75d>:12: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
# #cytoplasm
data = [F0_cytoplasm, T95c_cytoplasm, T58E_cytoplasm]
dat = pd.DataFrame({'WTB16F0': pd.Series(F0_cytoplasm), 'T95C': pd.Series(T95c_cytoplasm), 'T58E': pd.Series(T58E_cytoplasm)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-5, 15)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
sns.stripplot(data=dat,   size =2, color="black").set(xlabel = 'Experiment 1', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_F0_cytoplasm = np.median(F0_cytoplasm)
medians_T95c_cytoplasm = np.median(T95c_cytoplasm)
medians_T58E_cytoplasm = np.median(T58E_cytoplasm)



plt.annotate(round(medians_F0_cytoplasm,2), xy=(0.1, 0.48),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T95c_cytoplasm,2), xy=(1.1, 1.15),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T58E_cytoplasm,2), xy=(2.1, 0.36),fontsize = 16, weight='bold', color='darkblue')

# sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Cytoplasm', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-221-ffb48cdc6e8d>:11: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')

# %%
# #mixed
data = [F0_mixed, T95c_mixed, T58E_mixed]
dat = pd.DataFrame({'WTB16F0': pd.Series(F0_mixed), 'T95C': pd.Series(T95c_mixed), 'T58E': pd.Series(T58E_mixed)})


sns.set(font_scale =1.5, style="ticks", palette="colorblind", rc={'figure.figsize':(10,8)})
plt.ylim(-5, 15)
plt.hlines(y=3.5, xmin=-1.00, xmax=4, colors='crimson' , alpha =0.7, ls=':')
plt.hlines(y=10, xmin=-1.00, xmax=4, colors='purple' , alpha =0.7, ls=':')
plt.hlines(y=20, xmin=-1.00, xmax=4, colors='purple' ,  alpha =0.7,ls=':')
sns.violinplot(data=dat,  scale='count', palette='flare')
sns.stripplot(data=dat,   size =2, color="black").set(xlabel = 'Experiment 1', ylabel='% FRET Efficiency (Ef)')

# #medians
medians_F0_mixed= np.median(F0_mixed)
medians_T95c_mixed = np.median(T95c_mixed)
medians_T58E_mixed = np.median(T58E_mixed)



plt.annotate(round(medians_F0_mixed,2), xy=(0.1, 0.48),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T95c_mixed,2), xy=(1.1, 1.15),fontsize = 16, weight='bold', color='darkblue')
plt.annotate(round(medians_T58E_mixed,2), xy=(2.1, 0.36),fontsize = 16, weight='bold', color='darkblue')

# sns.stripplot(data=dat,   size=2, color="black")
plt.xlabel('Mixed', fontsize=18, weight='bold');
plt.ylabel('% FRET Efficiency (Ef)', fontsize=18, weight='bold');
# Out:
# <ipython-input-222-5244d1856c0d>:11: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='count'` for the same effect.
#   sns.violinplot(data=dat,  scale='count', palette='flare')
